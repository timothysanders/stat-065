# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# $$\Large\textbf{🏷 LAB 2-1 Types of Data Structures and Data Sets 🏷}$$

# %% [markdown]
# #### **Objectives:  By the end of this Lab, you will**
# * Know the list data structure and how to create one in native Python
# * Know the array data structure defined by Numpy Python library and its difference from the List
# * Know how to create a table-like data structure using Python pandas data frame with data that are manually entered, uploaded from a local file, imported from Google Drive, or directly read from an online source.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **1. List in Python and Array in Numpy Library**
#
# #### Sometimes we want to place items that are **similar** in a variable container.  In Python, this type of container is called $\color{blue}{\text{array}}$.
#
# #### Othertimes, we want to place items that are **NOT similar** in a variable container.  In Python, this type of container is called $\color{blue}{\text{list}}$.
#
# For example, we want to store students grades for several assignemnts.  In this case, we could create a container with student's name and place the score from each assignment in the container.  On the other hand, if we need to store data of a student's ID, majors, enrolled courses, payments, majors, and years in college.  In this case, the container with student's name will a combined data types of numbers and strings in a list.

# %% [markdown]
# ### **Syntax**
# * The syntax for an array or list is a pair of bracket **[  ]**
# *   The items inside the bracket belong to the same type separated with a comman such as numbers or strings.
# *   Examples: my_grade = [ 98, 85, 78, 70], students_names = ["name1", "name2", "name3"], or an_empty_array = [ ]

# %% [markdown]
# ###🔖 **$\color{blue}{\textbf{Lab Work:}}$  Practice creating a list, one array, and DataFrame with multiple arrays** insert a code cell and create an array with the name animals with at least three values of animals' names.

# %% [markdown]
# ###🧚 **$\color{orange}{\textbf{Tip:}}$  Common features of a List and Array**
#
# Both the list and array data structures are enclosed in **square brackets "[ ]"**, and allow indexing, slicing, and iterating.

# %% [markdown]
# ###🧚 **$\color{orange}{\textbf{Tip:}}$   Array vs. List**
#
# <details>
#   <summary><b>Comparison Table</b> </summary>
#
# |Array|List |
# |--|--|
# |Contains elements of different data types|Contains elements of same data types|
# |Do not need to be declared| Need to be declared|
# |Explicitly importing module is not required to declare a list|Need to import the module explicitly to declare an array|
# |Cannot handle arithmetic operations|Can handle arithmetic operations|
# |Can be nested inside another list|Must contain all elements of the same size|
# |Mostly used in the shorter sequence of data elements|Mostly used in the longer sequence of data elements|
# |Easy modifications like addition, deletion, and update of <br>data elements are done|It is difficult to modify an array since addition, deletion <br>and update operation is performed on a single element at a time|
# |We can print the entire list without the help of an explicit loop|To print or access array elements, we will require an explicit loop|
# |For easy addition of element, large memory storage is required|In comparison to the list, it is more compact in-memory size|
#
# </details>

# %% [markdown]
# ###🧚 **$\color{orange}{\textbf{Tip:}}$ When should you use list and when should you use array**
#
#
# <details>
#   <summary><b>Show Usages</b> </summary>
#
# * If you need to store a relatively short sequence of items and you **don't plan to do any mathematical operations** with it, a list is the preferred choice. This data structure will allow you to store an ordered, mutable, and indexed sequence of items without importing any additional modules or packages.
#
# * If you have a very **long sequence** of items, consider using an array. This structure offers more efficient data storage.
#
# * If you plan to do any **numerical operations** with your combination of items, use an array. Data analytics and data science rely heavily on (mostly NumPy) arrays.
#
# </details>

# %% [markdown]
# ###🔖 **$\color{blue}{\textbf{Lab Work:}}$  Practice creating a list, one array, and DataFrame with multiple arrays**

# %% [markdown]
# ### **a. Creating a list**: Create a variable using your own name for Python List that contains, the last four digits of some student ID, numer of courses enrolled in this semester, majors, and years in PCC.  You can makeup those values.

# %%
tim = [5467, 3, 2]
print(tim)
# Out:
# [5467, 3, 2]

# %% [markdown]
# ### **b. Index items in an array**
#   In Python – as in other programming langauges – the "things" in lists have a position, and we can get things from a list by asking for them by position. It's similar how a string's characters have positions, too.
#
# For historical reasons, computer scientists tend to start counting at 0, rather than 1. So to get the first item in the temperature array, ask for the "thing" in position 0 by typing temperature[0]:

# %% [markdown]
# ### **$\color{green}{\textbf{TO Do:}}$**
#
# ### **1.** Insert a code cell and create an array with the name temperature with four values of your estimated average temperatures of the four seasons in the city you live.  You can google to find the information
#
# ### **2.** Print the first and last emement in the list

# %%
# Temperature data from https://www.cityofpasadena.net/about-pasadena/pasadena-climate/
pasadena_temp = [70, 82, 87, 67]
print(f"The average temperatures for the four seasons are: {pasadena_temp}")
print(f"The first element of `pasadena_temp` is {pasadena_temp[0]}")
print(f"The last element of `pasadena_temp` is {pasadena_temp[3]}")
# Out:
# The average temperatures for the four seasons are: [70, 82, 87, 67]
# The first element of `pasadena_temp` is 70
# The last element of `pasadena_temp` is 67

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **2.  Dataframe: tables-like data structure**
#
# #### A **DataFrame** is a data structure that organizes data into a 2-dimensional table of rows and columns, much like a table and spreadsheet. DataFrames are one of the most common data structures used in modern data analytics because they are a flexible and intuitive way of storing and working with data in data science, machine learning, scientific computing, and many other data-intensive fields.
#
# #### **DataFrames are similar to tables or the spreadsheets** that you work with in Excel or Calc. In many cases, DataFrames are faster, interactive, easier to use, and more powerful than tables or spreadsheets because they’re an integral part of the Python and NumPy ecosystems for data analysis.

# %% [markdown]
# ### **Syntax**
#
# The `DataFrame()` function is used to create a data frame in Pandas. The syntax of creating a data frame is:
#
# ### `pandas.DataFrame(data, index, columns)`
# where,
#
# #### **data:** a list, dictionary, scalar value, series, ndarrays.
# #### **index:** It is optional, by default the index of the dataframe starts from 0 and ends at the last data value(n-1). It defines the row label explicitly.
#
# #### **columns:** This parameter is used to provide column names in the dataframe. If the column name is not defined by default, it will take a value from 0 to n-1.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ### **A. Create Pandas DataFrame with a list and dictionary**

# %% [markdown]
# ###🔖 **$\color{blue}{\textbf{Lab Work:}}$ Practice Creating a data frame from a list or dictionary**

# %% [markdown]
# #### **a. Creating an empty data frame**

# %%
import pandas as pd
data_frame = pd.DataFrame()
data_frame.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### **b. Creating Dataframe from Lists**

# %%
data_frame = pd.DataFrame([1, 2, 3])
data_frame.head()
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %% [markdown]
# ###**$\color{green}{\textbf{TO DO:}}$**
#
# Create a pandas data frame using a list of highest day temperature in the last seven days in your city (You can search on weather.com for the information)

# %%
# Data retrieved from https://www.wunderground.com/history/monthly/us/ca/altadena/KBUR
temperature_list = [88, 78, 78, 81, 77, 77, 76]
temperature_df = pd.DataFrame(temperature_list, columns=["temperature"])
temperature_df.head()
# Out:
#    temperature
# 0           88
# 1           78
# 2           78
# 3           81
# 4           77

# %% [markdown]
# #### **c. Creating Dataframe from Lists**
# To create DataFrame from dict of narray/list, all the narray must be of same length. If index is passed then the length index should be equal to the length of arrays. If no index is passed, then by default, index will be range(n) where n is the array length.

# %% [markdown]
# ###**$\color{green}{\textbf{TO DO:}}$**
#
# Create a pandas data frame using a dictionary with titles: "courses" and "units" you took in this semester.

# %%
courses = ["STAT-065", "MATH-003", "CS-034"]
units = [1, 4, 3]
semester = {"courses": courses, "units": units}
course_df = pd.DataFrame(semester)
course_df.head()
# Out:
#     courses  units
# 0  STAT-065      1
# 1  MATH-003      4
# 2    CS-034      3

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##  **B. Create Pandas DataFrame by reading data from files**

# %% [markdown]
# #### **[Pandas Syntax](https://pandas.pydata.org/docs/reference/io.html) for reading data in ```csv, excel,``` and ```json``` formats**
#
# ```import pandas``` \
# ```pandas.read_csv((file_path)``` \
# ```pandas.read_excel((file_path)``` \
# ```pandas.read_json((file_path)```

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ###   🔖 **$\color{blue}{\textbf{Lab Work:}}$ Creating Pandas DataFrame with Local Data Files**
#
# Open this [link](https://docs.google.com/spreadsheets/d/1mpaQoG1IcaMBG-yKYR-2L0JtgMw0DIqVQjeHnP9qSgo/edit?usp=sharing) to download the iris.csv file to your hard drive

# %% [markdown]
# ### **Step1: Upload a data file to Colab**

# %% [markdown]
# ###  **Upload local data files to Colab Manually**
# ####🧚 **$\color{red}{\textbf{warning:}}$  This method needs to repeat each time you open the Jupyter Notebooks**

# %% [markdown]
# #### **Method 1. Upload the local file Using icons by drag and drop**
# * Click the folder 📁 icon on the left edge panel
# * drag and your file to the panel.
# ##### **Click [here](https://www.3cmediasolutions.org/privid/387784?key=599b63affc27160c9cd28d160395d6a6e9600719)** to watch a 33 seconds video walk through on how to upload a file to Colab manually
#
# **```file_path = ``` the uploaded file name**

# %% [markdown]
# #### **Method 2: Upload the local file to Colab using code**
# ```
# from google.colab import files
# unloaded = files.upload()
# ```
# ####🧚 **$\color{orange}{\textbf{Tip:}}$  Click the file folder 📁 on the left to verify the uploaded file is there.**
# ####🧚 **$\color{red}{\textbf{Warning:}}$  Check the file name.  Google might adds another extension `.csv` at the end of the file name.**

# %% [markdown]
# ### **Step 2. Creating a pandas dataframe with an uploaded local file (```tip.csv``` as an example)**

# %%
iris_df = pd.read_csv("sample_data/Iris.csv")
iris_df.head()
# Out:
#    Index  sepal.length  sepal.width  petal.length  petal.width      species
# 0    1.0           5.1          3.5           1.4          0.2  Iris-setosa
# 1    2.0           4.9          3.0           1.4          0.2  Iris-setosa
# 2    3.0           4.7          3.2           1.3          0.2  Iris-setosa
# 3    4.0           4.6          3.1           1.5          0.2  Iris-setosa
# 4    5.0           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ###   🔖 **$\color{blue}{\textbf{Lab Work:}}$ Creating Pandas DataFrame with a .cvs file on google drive**
#
#
# ####🧚 **$\color{orange}{\textbf{Tip:}}$ Click [here](https://www.3cmediasolutions.org/privid/387810?key=d54232346840ff19f8393d333dd76ce8fa6a7736)** for a Walkthrough video of the four steps with a demo using a [data file](https://docs.google.com/spreadsheets/d/1ePsvDCrmWLkuUGw4b2OZ1W7N6ltX2jzjEJJ7u-G5qX4/edit#gid=0) on google drive.

# %% [markdown]
# ### **$\color{green}{\textbf{TO DO:}}$**
#
# * Find a csv data file
# * upload to your google drive
# * follow the instruction above to create a panda data frame

# %% [markdown]
# #### **Step 1:** Verify that the file share is set to **"Anyone with the link"**
# #### **Step 2:** Copy the URL to the data file on google drive (Not the shared link)
# #### **Step 3:** Create a variable to the google sheet and convert it to a CSV file format

# %% [markdown]
# #### **Step4:** To create a pandas data frame with the url

# %% [markdown]
# <font color = "red"> **New Google sheet URL naming:** </font> If your code does not work, check to see if the naming of the url after **edit** is `?grid=0`.  If yes, then use the following code to export the file to csv format

# %%
# Adapted code example from first answer https://stackoverflow.com/questions/56611698/pandas-how-to-read-csv-file-from-google-drive-public
sheet_url = "https://drive.google.com/uc?id=1DSHZfGhWD0KTI4j3OhV0A4NRvEDjQUKT"
df = pd.read_csv(sheet_url)
df.head()
# Out:
#    Index  sepal.length  sepal.width  petal.length  petal.width      species
# 0    1.0           5.1          3.5           1.4          0.2  Iris-setosa
# 1    2.0           4.9          3.0           1.4          0.2  Iris-setosa
# 2    3.0           4.7          3.2           1.3          0.2  Iris-setosa
# 3    4.0           4.6          3.1           1.5          0.2  Iris-setosa
# 4    5.0           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ###  🔖 **$\color{blue}{\textbf{Lab Work:}}$ Creating Pandas DataFrame with raw online data file with an internet URL**
#
# #### **We will use Tip data set you will see a list of hosting web sites. This[ link](https://raw.githubusercontent.com/plotly/datasets/master/violin_data.csv) is the first URL to the Tip Data set**

# %% [markdown]
# #### **Step1:** Copy the url fromt he address bar of the website with the data source
# #### **Step 2:** Define a variable for the URL

# %% [markdown]
# #### **Step 3:** Create a pandas data frame

# %% [markdown]
# Syntax
#
# ```
#     import pandas as pd
#     url = "file_path"  # file_path will be replaced by real url"
#     df = pd.read_csv(url)
#     df.head()
# ```

# %% [markdown]
# ### 🧚 **$\color{green}{\textbf{TO DO:}}$**
#
# 1. clikc the link to a look at the raw data with the  https://raw.githubusercontent.com/fivethirtyeight/data/master/fandango/fandango_scrape.csv
#
# 2. Use the above url as a file_path to create a dataframe

# %%
file_path = "https://raw.githubusercontent.com/fivethirtyeight/data/master/fandango/fandango_scrape.csv"
fandango_df = pd.read_csv(file_path)
fandango_df.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ####  🔖 **$\color{blue}{\textbf{Lab Work:}}$ Creating Pandas DataFrame with by the retrieve the path to the file on your Google Drive**
#
# * You can use existing or upload any .csv file on your google drive.
# * I will an air quality data file in this **[link](https://drive.google.com/file/d/1_reDnXuIXlU-g2g1RgAzDKYa_coE_yCz/view?usp=sharing)**. I used this data to illustrate AI Engineering with Neurolnetwork.
#
# #### **Step 1:** Use the following code to mount your google drive associated with the current profile.
#
# * You need to verify your credentials.
# * Once your Google Drive is mounted, you should see output `Mounted at /content/gdrive`

# %% [markdown]
# #### **Step 2:** Find the file path in the following steps:
#
# <font color = "orange"> **NOTE:** </font> *This method allows you to import any file on your Google Drive to the Jupyer Notebook.*
#
# >> >***open*** 📁 on the left panel
#
# >>$⟹$ ***click*** ▶ next to the `gdrive`
#
# >>$⟹$  ***click*** ▶ next to the `MyDrive`
#
# >>$⟹$ ***click*** ▶ to the folder $\cdots$ find the file
#
# >>$⟹$ ***right-click*** $\color{red}{\mathbf{\vdots}}$ on the right and choose "Copy path" on the dropdown menu.

# %% [markdown]
# #### **Step 3:** Create a Panda Data Frame

# %%
air_quality_df = pd.read_csv("drive/MyDrive/STAT-065/air-quality.csv")
air_quality_df.head()
# Out:
#   No Profile Tanggal Jam O3 CO NO2 SO2 NO CO2 VOC PM1 PM2.5 PM4 PM10 TSP TEMP HUM WS WD ISPU Status
# 0  1 BANDUNG 2019-05-19 00:04:19 21.35 0.78 6.77 ...
# 1  2 BANDUNG 2019-05-19 00:15:01 5.93 0.82 14.87 ...
# 2  3 BANDUNG 2019-05-19 00:30:06 6.62 0.63 22.24 ...
# 3  4 BANDUNG 2019-05-19 00:49:19 13.29 0.44 19 5....
# 4  5 BANDUNG 2019-05-19 01:04:19 2.44 0.47 26.74 ...
