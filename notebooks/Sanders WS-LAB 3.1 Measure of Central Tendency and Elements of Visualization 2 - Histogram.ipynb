# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# **$$\large\textbf{Introduction to Central Tendency}$$**
# **$$\large\textbf{$$Elements of Visualization 2 - Histogram}$$**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Introduction to Mode, Median, and Mode**

# %% [markdown]
# ### **1.** Statistical and Mathematical Definitions
# <details>
#   <summary><font size = 3><b>Show Introduction</b></font></summary>
# A measure of central tendency is a statistical measure that identifies a single value as representative of an entire distribution. It's a way to describe the center of a data set. There are three main measures of central tendency: the mean, the median, and the mode.
#
# ###**The two most widely used measures of the "center" of the data are the mean (average) and the median**.
#   </details>
#
#
# <details>
#   <summary><font size = 3><b>Show Formula for Calculating Mean</b></font></summary>
#
# The greek letter**$\mu$** is denoted for **a population mean**. $N$ is the population size.
# $$\mu = \frac{\sum_{i}^{}x_{i}}{N}$$
#
# The $\overline{x}$ is denoted for **a sample mean**, which is an estimate of the **population mean**.  $n$ is the sample size.
# $$\overline{x} = \frac{\sum_{i}^{}x_{i}}{n}$$
#
# $∑$ represents the summation \
# $x_i$ represents a data value from the population (if we are calculating the population mean) or from the sample (if we are calculating the sample mean). \
#
# $\color{red}{\text{NOTE:}}$ The words "mean" and "average" are often used interchangeably.  The substitution of one word for the other is common practice.  The technical term is "arithmetic mean" and "average" is technically a center location.  However, in practice among non-statisticians, "average" is commonly accepted for "arithmetic mean."
# </details>
#
# <details>
#   <summary><b><font size = 3>Show Definition of Median</b></font></summary>
#
# If the total number of data points, $n$, is an <b>odd</b> number, then there is only one middle term.  The median is given by:
# $$\text{median} = (\frac{n+1}{2})^{\text{th}} \text{ term}$$
#
# If the total number of the data points, ($n$), is an <b>even</b> number, then the median is the average of the two middle terms.  The formula is given below:
# $$\text{median} = \frac{ (\frac{n}{2})^{\text{th}} \text{ term} + (\frac{n}{2}+1)^{\text{th}} \text{ term}}{2}$$
#
# $\color{red}{\text{NOTE:}}$ The **median** is a number that measures the "center" of the data. You can think of the
# median as the "middle value," but it does not actually have to be one of the observed values. It is a number that separates ordered data into halves. Half the values are the
# same number or smaller than the median, and half the values are the same number or larger.
#   </details>
# <details>
#   <summary><font size = 3><b>Show Definition of Mode</b></font></summary>
#
# The <b>mode</b> is the most frequently occurring score or value in a sample.  There could be more than one mode in a sample.  When a sample has two modes we say it is **bimodal**.  When the sample has three modes we say it is **trimodal**.  When there are many modes we say it the sample is **multimodal**.
# </details>

# %% [markdown]
# ### **2. ` Python Syntax for computing mode, median, and mean of raw data`**

# %% [markdown]
# > #### **Calculating mean and median**
# >> Python commands for calculating mean and median
#
# > * Using Python ```statistics``` library
#
# >>> ```import statistics``` \
# >>> ```statistics.mean(sample_list)```\
# >>>```statistics.median(sample_list)```\=
#
# > * Using ```numpy``` library
#
# >>> ```import numpy``` \
# >>> ```numpy.mean()```\
# >>> ```numpy.median()```

# %% [markdown]
# > #### **Calculating mode**
#
# > *  Unique mode in the data set \
# >>  ```import statistics``` \
# >>  ```statistics.mode()```
#
# > * Smallest multiple modes Multiple modes \
#  >>```from scipy import stats``` \
# >> ```stats.mode()``` \
#
# >$\color{red}{\text{NOTE:}}$ ```stats.mode()``` returns an array of ```mode``` and a corresponding array of ```count``` for each mode.
#
# >* multiple mode (only for Python 3.8 or above)
#  >> ```import statistics``` \
#  >> ```statistics.multimode()```

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Definition of Histograms**
#
#
# > A **histogram** is a bar graph for continuous data.  The data is grouped into different classes and each class corresponds to a bar.  The resulting histogram consists of contiguous (adjoining) bars. It has both a horizontal axis and a vertical axis.  The vertical axis is labeled either **frequency** or **relative frequency** (or percent frequency or probability).
#
# > The <b>advantage</b> of a histogram is that it can readily display a data set consisting of 100 values or more.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work 1:}}$ Practice finding mean, median and mode of data sample in a list**
#
#
# <details>
#   <summary><b>Show problem</b></summary>
#
# AIDS data indicating the number of months a patient with AIDS lives after taking a new antibody drug are as follows
# 3, 40, 22, 16, 8, 34, 10, 16, 16, 33, 13, 13, 13, 13, 14, 15,
# 34, 15, 24, 23, 34, 16, 10, 21, 5, 2, 101, 43, 17, 34, 24.
# Find its mean and median, and mode(s)
# </details>

# %% [markdown]
# ### **Calculate the mean manually by definition**

# %%
mean = (3 + 40 + 22 + 16 + 8 + 34 + 10 + 16 + 16 + 33 + 13 + 13 + 13 + 13 + 14 + 15 + 34 + 15 + 24 + 23 + 34 + 16 + 10 + 21 + 5 + 2 + 101 + 43 + 17 + 34 + 24) / 44
corrected_mean = (3 + 40 + 22 + 16 + 8 + 34 + 10 + 16 + 16 + 33 + 13 + 13 + 13 + 13 + 14 + 15 + 34 + 15 + 24 + 23 + 34 + 16 + 10 + 21 + 5 + 2 + 101 + 43 + 17 + 34 + 24) / 31
# Since there are 31 data points (instead of 44), we use the corrected_mean variable here
print(f"The mean of the data is {corrected_mean} months.")
# Out:
# The mean of the data is 22.0 months.

# %% [markdown]
# Median: Since there are 31 data points, we need to sort the data first and find the average of the middle two data points.
#
# Mode: We need to count how often each data point appears in the data set:

# %% [markdown]
# ### **Using ```statistics``` to calculate mean and median**

# %%
import statistics
aids = [3, 40, 22, 16, 8, 34, 10, 16, 16, 33, 13, 13, 13, 13, 14, 15, 34, 15, 24, 23, 34, 16, 10, 21, 5, 2, 101, 43, 17, 34, 24]

num_data = len(aids)
mean = statistics.mean(aids)
median = statistics.median(aids)
print(f"""The number of data points: {num_data}
The mean of the data: {mean}
The median of the data: {median}
""")
# Out:
# The number of data points: 31
# The mean of the data: 22
# The median of the data: 16

# %%
import numpy as np

sample_mean_aids = mean / np.sqrt(num_data)
print(f"The sample mean of the data: {sample_mean_aids}")
# Out:
# The sample mean of the data: 3.951316644589048

# %% [markdown]
# ### **Using ```numpy``` to calculate mean and median**

# %%
mean_aids = np.mean(aids) # population mean
sample_mean_aids = mean / np.sqrt(num_data)
median_aids = np.median(aids) # population median
print(f"""The number of data points: {num_data}
The mean of the data: {mean_aids}
The median of the data: {median_aids}
""")
print(f"The sample mean of the data: {sample_mean_aids}")
# Out:
# The number of data points: 31
# The mean of the data: 22.0
# The median of the data: 16.0
#
# The sample mean of the data: 3.951316644589048

# %% [markdown]
# ### **Using ```scipy``` to find the smallest mode**

# %%
import scipy.stats as stats

mode = stats.mode(aids)
print(f"The smallest mode: {mode.mode} (count: {mode.count})")
# Out:
# The smallest mode: 13 (count: 4)

# %% [markdown]
# ### **Using `collection` and `itertools` python library to find multiple modes**

# %% [markdown]
# 1. **Using `Counter` to Determine Frequencies**:
# To understand the main line of code that follows, we need to be familiar with the `Counter` function
# The `Counter` function computes the occurrences of each unique element in the list, returning a dictionary-like collection where keys are the unique numbers from the list, and values are their respective counts (frequencies).

# %%
from collections import Counter
from itertools import groupby

aids = [3, 40, 22, 16, 8, 34, 10, 16, 16, 33, 13, 13, 13, 13, 14, 15, 34, 15, 24, 23, 34, 16, 10, 21, 5, 2, 101, 43, 17, 34, 24]
frequency_dictionary = Counter(aids)
print(f"""The dictionary(key: value) pair as month: frequency in our problem
{frequency_dictionary}
""")
# Out:
# The dictionary(key: value) pair as month: frequency in our problem
# Counter({16: 4, 34: 4, 13: 4, 10: 2, 15: 2, 24: 2, 3: 1, 40: 1, 22: 1, 8: 1, 33: 1, 14: 1, 23: 1, 21: 1, 5: 1, 2: 1, 101: 1, 43: 1, 17: 1})

# %% [markdown]
# 2. **Convert the count from value:frequency in dictionary format to (value, frequency) in a tuple format**:
# ```python
# Counter(sample).most_common()
# ```
# The `most_common()` function is applied to the result of `Counter(sample)`. This function sorts the elements from the sample based on their frequency in descending order, returning a list of tuples. Each tuple contains a number from `sample` and its respective frequency.

# %%
frequency_tuples = frequency_dictionary.most_common()
print(f"""The months and the frequency pairs in tuple formats:
{frequency_tuples}""")
# Out:
# The months and the frequency pairs in tuple formats:
# [(16, 4), (34, 4), (13, 4), (10, 2), (15, 2), (24, 2), (3, 1), (40, 1), (22, 1), (8, 1), (33, 1), (14, 1), (23, 1), (21, 1), (5, 1), (2, 1), (101, 1), (43, 1), (17, 1)]

# %% [markdown]
# 3. **Grouping by Frequencies using `groupby`**:
# ```python
# freqs = groupby(Counter(sample).most_common(), lambda x: x[1])
# ```
# Here, `groupby` is employed to group the tuples based on their frequencies (counts). The lambda function `lambda x: x[1]` is designed to extract the second item (frequency) from each tuple for the purpose of grouping. As a result, `freqs` will be an iterable of groups, with each group containing tuples that share the same frequency.
#
# Effectively, `freqs` groups numbers from the `sample` list based on how many times they appear. This is handy for identifying which numbers have the same frequency within the list.

# %%
frequencies = groupby(frequency_tuples, lambda x: x[1])
print(f"The output memory address is {frequencies}")
# Out:
# The output memory address is <itertools.groupby object at 0x79c6b2a99cb0>

# %% [markdown]
# 4. **Iterate each group in sorted in descending order of frequency group to print out all the values in the first group (mode with the highest frequency)**:

# %%
print("The mode(s) with the highest frequency of occurrence in the data set are")
print([modes for modes, counter in next(frequencies)[1]])
# Out:
# The mode(s) with the highest frequency of occurrence in the data set are
# [16, 34, 13]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##**$\color{green}{\textbf{TO DO 1: }}$ Practice Computing mean, median, and mode of a dataset: Try with all commands**
#
#
# <details>
# <summary><b>Show problem</b></summary>
#   Write Python Code to find the mean, median, and mode of a exam scores in a statistics class
#
# 84, 50, 72, 53, 72, 84, 59, 72, 59, 63, 84, 63, 72, 76, 78,72,  81, 83, 72, 90, 93, 97
# </details>

# %% [markdown]
# ### **Instructions:**
# * Create a list using the data from the problem
# * Compute the following statistics values below for describing central tendency
# * Print out the output using `f-string` with a meaninful description.
# ###🧚 **$\color{orange}{\textbf{Tip:}}$ You only have to import any python library once**

# %%
exam_scores = [84, 50, 72, 53, 72, 84, 59, 72, 59, 63, 84, 63, 72, 76, 78, 72, 81, 83, 72, 90, 93, 97]

# %% [markdown]
# ### **1. Use either `statistics` or `numpy` library to calculate the mean and median**

# %%
exam_mean = np.mean(exam_scores)
exam_median = np.median(exam_scores)
print(f"The numpy mean of the exam scores is: {exam_mean}")
print(f"The numpy median of the exam scores is: {exam_median}")
exam_mean = statistics.mean(exam_scores)
exam_median = statistics.median(exam_scores)
print(f"The statistics mean of the exam scores is: {exam_mean}")
print(f"The statistics median of the exam scores is: {exam_median}")
# Out:
# The numpy mean of the exam scores is: 74.04545454545455
# The numpy median of the exam scores is: 72.0
# The statistics mean of the exam scores is: 74.04545454545455
# The statistics median of the exam scores is: 72.0

# %% [markdown]
# ### **2. Find the smallest mode using `statistics` library**

# %%
# The statistics.mode() function is documented here: https://docs.python.org/3/library/statistics.html#statistics.mode
# exam_mode = statistics.multimode(exam_scores)
exam_mode = statistics.mode(exam_scores)
print(f"The smallest mode of the exam scores is: {exam_mode}")
# Out:
# The smallest mode of the exam scores is: 72

# %% [markdown]
# ### **3. Find all the smallest mode using `collection` and `itertools` python library**

# %%
exam_frequencies = groupby(Counter(exam_scores).most_common(), lambda x: x[1])
exam_modes = [modes for modes, counter in next(exam_frequencies)[1]]
print(f"The mode(s) with the highest frequency of occurrence in the data set are: {exam_modes}")
print(f"The smallest mode in the data set is: {min(exam_modes)}")
# Out:
# The mode(s) with the highest frequency of occurrence in the data set are: [72]
# The smallest mode in the data set is: 72

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work 2:}}$ Create a histogram with <font color = "red">raw </font>data and a vertical line for mean with a list data structure.**
#
# <details>
#   <summary><b>Show data</b></summary>
#
#   The following data are the heights (in inches to the nearest half an inch) of 100 male semiprofessional soccer players.  The heights:
#
# 72.5, 73, 60, 60.5, 61, 71, 61, 61.5, 63.5, \
# 63.5, 63.5, 74, 64, 69.5, 69.5, 64, 64, 72, \
# 73.5, 64, 64, 70, 70.5, 64, 64, 64.5, 64.5, \
# 64.5, 64.5, 70, 70, 72, 64.5, 64.5, 64.5, 64.5, \
# 66, 68, 69, 66, 70, 70.5, 66, 66, 69, 69.5, \
# 66, 66, 69, 66, 72, 72.5, 66, 66, 66.5, 66.5, \
# 66.5, 66.5, 66.5, 66.5, 66.5, 66.5, 66.5, 66.5, \
# 67, 69, 67, 67, 70, 69, 69.5, 70, 70.5, \
# 67, 67, 71, 67, 69, 67, 67, 66, 66.5, 67, \
# 67, 69, 67, 67, 67.5, 67.5, 69, 67.5, 67.5, \
# 67.5, 67.5, 67.5, 68, 69, 71, 69, 69.5 \
#
# </details>

# %% [markdown]
# #### **A. Using [_matplotlib_](https://matplotlib.org/) Python Library**
# Click [here](https://www.statology.org/matplotlib-bin-size/) for other options to specify the bin sizes and hover text of a histogram with matplotlib

# %%
import matplotlib.pyplot as plt

# Create our data set
raw_player_heights = [
    72.5, 73, 60, 60.5, 61, 71, 61, 61.5, 63.5,
    63.5, 63.5, 74, 64, 69.5, 69.5, 64, 64, 72,
    73.5, 64, 64, 70, 70.5, 64, 64, 64.5, 64.5,
    64.5, 64.5, 70, 70, 72, 64.5, 64.5, 64.5, 64.5,
    66, 68, 69, 66, 70, 70.5, 66, 66, 69, 69.5,
    66, 66, 69, 66, 72, 72.5, 66, 66, 66.5, 66.5,
    66.5, 66.5, 66.5, 66.5, 66.5, 66.5, 66.5, 66.5,
    67, 69, 67, 67, 70, 69, 69.5, 70, 70.5,
    67, 67, 71, 67, 69, 67, 67, 66, 66.5, 67,
    67, 69, 67, 67, 67.5, 67.5, 69, 67.5, 67.5,
    67.5, 67.5, 67.5, 68, 69, 71, 69, 69.5
]

# %%
# Compute central tendency
mean_height = np.mean(raw_player_heights)
median_height = np.median(raw_player_heights)
plt.Figure(figsize=(15, 7))
# Histogram
plt.hist(raw_player_heights, label="Raw data counts")
plt.xlabel("Height in inches")
plt.ylabel("Count")

plt.axvline(mean_height, linestyle="--", linewidth=2, color="orange", label=f"Mean height (inches): {mean_height: .1f}")
plt.axvline(median_height, linestyle=":", linewidth=2, color="red", label=f"Median height (inches): {median_height: .1f}")

plt.legend(
    loc="upper right",
    bbox_to_anchor=[1.50, 1],
    shadow=True,
    fontsize="medium"
)
plt.title("Height Distribution of Semi-professional Soccer Players")
plt.show()

# %% [markdown]
# ####**B. Using [_plotly_](https://plotly.com/python/) (R and Python) for interactive graphs**
#
# <details>
#   <summary><b>Show options histnorm</b></summary>
#
# The default mode is to represent the count of samples in each bin. With the histnorm argument, you can use
#
# ```histnorm ='percent'``` or ```histnorm ='probability'``` for representing the percentage or fraction of samples in each bin \
#
# or ```histnorm ='density '``` for a density histogram (the sum of all bar areas equals the total number of sample points, density),
#
# or ```histnorm ='probability density '``` for a probability density histogram (the sum of all bar areas equals 1, probability density).
#
# **Hover text in plotly**
#
# 1. ```hovermode=’closest’``` \
# wherein a single hover label appears for the point directly underneath the cursor.
#
# 2. ```hovermo= "x unified```
# a single hover label appears per trace, for points at the same x value as the cursor.
# </details>

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(
    go.Histogram(
        x=raw_player_heights,
        histnorm="density",
        name="raw data",
        xbins=dict(
            start=59.95,
            end=75.95,
            size=2
        ),
        autobinx=False
    ),
)
fig.add_vline(
    x=mean_height,
    line=dict(
        color="magenta",
        width=4,
        dash="dash"
    ),
    name=f"Mean height: {mean_height}",
    annotation_text="Mean height",
    annotation_position="top right",
    annotation_font_size=10
)
fig.add_vline(
    x=median_height,
    line=dict(
        color="cyan",
        width=4,
        dash="dash"
    ),
    name=f"Median height: {median_height}",
    annotation_text="Median height",
    annotation_position="top left",
    annotation_font_size=10
)
fig.update_layout(
    height=600,
    width=900,
    title="Height Distribution of Semi-professional Soccer Players",
    title_x=0.5,
    xaxis=dict(
        title="Height in inches",
        tick0=59.95,
        dtick=2
    ),
    yaxis_title="Counts",
    hovermode="x unified",
    showlegend=True,
    font_size=18
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3732e1d3-4d66-45aa-b5aa-ec7e9f66f1d9" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3732e1d3-4d66-45aa-b5aa-ec7e9f66f1d9")) {                    Plotly.newPlot(                        "3732e1d3-4d66-45aa-b5aa-ec7e9f66f1d9",                        [{"autobinx":false,"histnorm":"density","name":"raw data","x":[72.5,73,60,60.5,61,71,61,61.5,63.5,63.5,63.5,74,64,69.5,69.5,64,64,72,73.5,64,64,70,70.5,64,64,64.5,64.5,64.5,64.5,70,70,72,64.5,64.5,64.5,64.5,66,68,69,66,70,70.5,66,66,69,69.5,66,66,69,66,72,72.5,66,66,66.5,66.5,66.5,66.5,66.5,66.5,66.5,66.5,66.5,66.5,67,69,67,67,70,69,69.5,70,70.5,67,67,71,67,69,67,67,66,66.5,67,67,69,67,67,67.5,67.5,69,67.5,67.5,67.5,67.5,67.5,68,69,71,69,69.5],"xbins":{"end":75.95,"size":2,"start":59.95},"type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillm ...

# %% [markdown]
# ###🧚 **$\color{orange}{\textbf{Tip: }}$** Hover the mouse over the top of each bar to see the numerical value of the percentage of each bar

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work 3:}}$ Create an App with UI for variation of bin sizes.**

# %% [markdown]
# #### **A. Add a slider to control the $\color{red}{\text {number of bins}}$ in `matplotlib.pyplot`.**

# %%
# @title Use the slider to adjust the number of bins for the histogram {"run":"auto"}
bin_nums = 10 # @param {"type":"slider","min":1,"max":50,"step":1}

plt.Figure(figsize=(15, 7))
# Histogram
plt.hist(raw_player_heights, bins=bin_nums, label="Raw data counts")
plt.xlabel("Height in inches")
plt.ylabel("Count")

plt.axvline(mean_height, linestyle="--", linewidth=2, color="orange", label=f"Mean height (inches): {mean_height: .1f}")
plt.axvline(median_height, linestyle=":", linewidth=2, color="red", label=f"Median height (inches): {median_height: .1f}")

plt.legend(
    loc="upper right",
    bbox_to_anchor=[1.50, 1],
    shadow=True,
    fontsize="medium"
)
plt.title("Height Distribution of Semi-professional Soccer Players")
plt.show()

# %% [markdown]
# #### <font color = "orange"><b> Note: </b></font>**No matter what bin sizes we set, the** <font color = "red"> <b> mean height remains unchanged.</b></font>

# %% [markdown]
# #### **B. Add a slider to control the $\color{red}{\text {bin size}}$ in `plotly.graph_objects`**

# %%
# @title Use the slider to adjust the bin size between 59.95 and 75.95 {"run":"auto"}
bin_size = 2 # @param {"type":"number"}
fig = go.Figure()
fig.add_trace(
    go.Histogram(
        x=raw_player_heights,
        histnorm="density",
        name="raw data",
        xbins=dict(
            start=59.95,
            end=75.95,
            size=bin_size
        ),
        autobinx=False
    ),
)
fig.add_vline(
    x=mean_height,
    line=dict(
        color="magenta",
        width=4,
        dash="dash"
    ),
    name=f"Mean height: {mean_height}",
    annotation_text="Mean height",
    annotation_position="top right",
    annotation_font_size=10
)
fig.add_vline(
    x=median_height,
    line=dict(
        color="cyan",
        width=4,
        dash="dash"
    ),
    name=f"Median height: {median_height}",
    annotation_text="Median height",
    annotation_position="top left",
    annotation_font_size=10
)
fig.update_layout(
    height=600,
    width=900,
    title="Height Distribution of Semi-professional Soccer Players",
    title_x=0.5,
    xaxis=dict(
        title="Height in inches",
        tick0=59.95,
        dtick=2
    ),
    yaxis_title="Counts",
    hovermode="x unified",
    showlegend=True,
    font_size=18
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f01dba85-dfa8-4e6b-9f52-c58dd9813b02" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f01dba85-dfa8-4e6b-9f52-c58dd9813b02")) {                    Plotly.newPlot(                        "f01dba85-dfa8-4e6b-9f52-c58dd9813b02",                        [{"autobinx":false,"histnorm":"density","name":"raw data","x":[72.5,73,60,60.5,61,71,61,61.5,63.5,63.5,63.5,74,64,69.5,69.5,64,64,72,73.5,64,64,70,70.5,64,64,64.5,64.5,64.5,64.5,70,70,72,64.5,64.5,64.5,64.5,66,68,69,66,70,70.5,66,66,69,69.5,66,66,69,66,72,72.5,66,66,66.5,66.5,66.5,66.5,66.5,66.5,66.5,66.5,66.5,66.5,67,69,67,67,70,69,69.5,70,70.5,67,67,71,67,69,67,67,66,66.5,67,67,69,67,67,67.5,67.5,69,67.5,67.5,67.5,67.5,67.5,68,69,71,69,69.5],"xbins":{"end":75.95,"size":2,"start":59.95},"type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillm ...

# %% [markdown]
# ### **Write a short paragraph about your observations:**
# > * #### How does the bin size affect the distribution shape?
# >> The bin size affects the distribution a lot; too large covers the detailed shape, too small, and the overall shape is not visible.
# > * #### What would be your choice of an optimal bin size such that the histogram reveals the most significant features of the data set?  **Leave the slider in the position of your optimal choice.**.
# >> (3.0)
# > * #### How does the bin size affect the mean and median of the data set?
# >> #### <font color = "orange"><b> Note: </b></font>**No matter what bin sizes we set, the** <font color = "red"> <b> mean height remains unchanged.</b></font>
# > * #### How are the mean and median related in the data set?
# >> #### Mean is on the right of the median; the data is right-skewed.

# %% [markdown]
# Based on our experiments with the forms in the previous two graphs, we can see how the bin size and the number of bins can dramatically change how much information someone can easily get from a histogram. If the bin size is too granular, it can obscure the ability to identify any trends in the data, as you end up with something that is close to the original data points. If the bin size is too coarse, it will cover up any nuance with just a few buckets and flattens the distribution.
#
# For the data distribution, I like the bin size of 2 for revealing the most significant features of the data set, as it shows that the data is approximately normally distributed, but it also shows the interesting drop on the left hand side of the histogram.
#
# The bin size has no impact on the mean and median of the data set, these are static values that are based on our sample data and are not impacted by how the data is displayed.
#
# Our mean and median values are fairly close together, but the mean is greater than the median, which means that our data set is positively skewed, or right-skewed.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##**$\color{green}{\textbf{TO DO 2:}}$**
#
# <details>
#   <summary><b><font size = 3px>Show data for TODO 2</b></font></summary>
# The following data set is comprised of shoe sizes of 50 male students.
#
# 9, 9, 9.5, 9.5, 10, 10, 10, 10, 10, 10, 10.5, \
# 10.5, 10.5, 10.5, 10.5, 10.5, 10.5, 10.5,\
# 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, \
# 11, 11, 11.5, 11.5, 11.5, 11.5, 11.5, 11.5, 11.5, \
# 12, 12, 12, 12, 12, 12, 12, 12.5, 12.5, 14, 14, 14
#
# </details>

# %% [markdown]
# ### **1. Create an interactive histogram**

# %%
import pandas as pd

shoe_sizes = {
    "sizes": [
        9, 9, 9.5, 9.5, 10, 10, 10, 10, 10, 10, 10.5,
        10.5, 10.5, 10.5, 10.5, 10.5, 10.5, 10.5,
        11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
        11, 11, 11.5, 11.5, 11.5, 11.5, 11.5, 11.5, 11.5,
        12, 12, 12, 12, 12, 12, 12, 12.5, 12.5, 14, 14, 14
    ]
}

shoe_size_df = pd.DataFrame(shoe_sizes)

shoe_size_mean = np.mean(shoe_size_df.sizes)
print(f"The mean shoe size is: {shoe_size_mean: .1f}")
shoe_size_median = np.median(shoe_size_df.sizes)
print(f"The median shoe size is: {shoe_size_median}")
# Out:
# The mean shoe size is:  11.1
# The median shoe size is: 11.0

# %% [markdown]
# ### **Instructions:**
# > * Create a `pandas DataFrame` with the raw data
# > * Compute the mean of the shoe size data set
# > * Plot a histogram of the raw data and the vertical of the mean you computed.
# > * Create a vertical line to represent the mean.
# > * Create a vertical line to represent the median.
# > * Create proper labels for the axes and a title.
# >> **Note:** The mean could be more than 9 decimal places so use the `f-string` format to keep only 1 decimal place.  For example, if you used `size_mean` for mean size, your `f-string` should be `f"mean shoe size = {size_mean: .1f}"`
#
# >* Adjust the size of the plot, set the appropriate graph title and choose the position of the legend.

# %%
fig = go.Figure()
fig.add_trace(
    go.Histogram(
        x=shoe_size_df.sizes,
        histnorm="density",
        name="Shoe sizes",
        autobinx=True
    ),
)
fig.add_vline(
    x=shoe_size_mean,
    line=dict(
        color="magenta",
        width=4,
        dash="dash"
    ),
    name=f"Mean shoe size: {shoe_size_mean: .1f}",
    annotation_text="Mean shoe size",
    annotation_position="top right",
    annotation_font_size=10
)
fig.add_vline(
    x=shoe_size_median,
    line=dict(
        color="cyan",
        width=4,
        dash="dash"
    ),
    name=f"Median shoe size: {shoe_size_median}",
    annotation_text="Median shoe size",
    annotation_position="top left",
    annotation_font_size=10
)
fig.update_layout(
    height=600,
    width=900,
    title="Distribution of Shoe Sizes for Male Students",
    title_x=0.5,
    yaxis_title="Counts",
    hovermode="x unified",
    showlegend=True,
    font_size=18
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6e6c9bf4-1d24-4028-8794-8b75b46361ed" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e6c9bf4-1d24-4028-8794-8b75b46361ed")) {                    Plotly.newPlot(                        "6e6c9bf4-1d24-4028-8794-8b75b46361ed",                        [{"autobinx":true,"histnorm":"density","name":"Shoe sizes","x":[9.0,9.0,9.5,9.5,10.0,10.0,10.0,10.0,10.0,10.0,10.5,10.5,10.5,10.5,10.5,10.5,10.5,10.5,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.5,11.5,11.5,11.5,11.5,11.5,11.5,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.5,12.5,14.0,14.0,14.0],"type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpola ...

# %% [markdown]
# ### **2. Made your histogram into an app alowing users to explore the distribution by adjusting hte bin sizes.**
#
# #### **Instructions:**
# * Copy the code above to a code cell below
# * Create a form for your code block and adjust the addribute to "auto execute the code"
# * Create a slider using Google Form Field to replace the bin size variable 'size = 'to create a histogram:
# * Set `size` to a variable and link it to a slider via the "form field"

# %%
# @title Use the slider to adjust the bin size between 9 and 15 {"run":"auto"}
bin_size = .5 # @param {"type":"number"}
fig = go.Figure()
fig.add_trace(
    go.Histogram(
        x=shoe_size_df.sizes,
        histnorm="density",
        name="Shoe sizes",
        xbins=dict(
            start=9,
            end=15.5,
            size=bin_size
        ),
        autobinx=False
    ),
)
fig.add_vline(
    x=shoe_size_mean,
    line=dict(
        color="magenta",
        width=4,
        dash="dash"
    ),
    name=f"Mean shoe size: {shoe_size_mean: .1f}",
    annotation_text="Mean shoe size",
    annotation_position="top right",
    annotation_font_size=10
)
fig.add_vline(
    x=shoe_size_median,
    line=dict(
        color="cyan",
        width=4,
        dash="dash"
    ),
    name=f"Median shoe size: {shoe_size_median}",
    annotation_text="Median shoe size",
    annotation_position="top left",
    annotation_font_size=10
)
xaxis=dict(
        title="Shoe Size",
        tick0=9,
        dtick=2
    ),
fig.update_layout(
    height=600,
    width=900,
    title="Distribution of Shoe Sizes for Male Students",
    title_x=0.5,
    yaxis_title="Counts",
    hovermode="x unified",
    showlegend=True,
    font_size=18
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="afc76741-1616-4f5d-8c7c-276ce7f7a9ad" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afc76741-1616-4f5d-8c7c-276ce7f7a9ad")) {                    Plotly.newPlot(                        "afc76741-1616-4f5d-8c7c-276ce7f7a9ad",                        [{"autobinx":false,"histnorm":"density","name":"Shoe sizes","x":[9.0,9.0,9.5,9.5,10.0,10.0,10.0,10.0,10.0,10.0,10.5,10.5,10.5,10.5,10.5,10.5,10.5,10.5,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.0,11.5,11.5,11.5,11.5,11.5,11.5,11.5,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.5,12.5,14.0,14.0,14.0],"xbins":{"end":15.5,"size":0.5,"start":9},"type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks": ...

# %% [markdown]
# ### **3.  Write a short paragraph about your observations:**
# > * How does the bin size affect the distribution shape?
# > * What would be your choice of an optimal bin size such that the histogram reveals the most significant features of the data set?  **Leave the slider in the position of your optimal choice.**.
# > * How does the bin size affect the mean and median of the data set?
# > * How are the mean and median related in the data set?

# %% [markdown]
# Based on our experiments with the forms in the previous two graphs, we can see how the bin size and the number of bins can dramatically change how much information someone can easily get from a histogram. If the bin size is too granular, it can obscure the ability to identify any trends in the data, as you end up with something that is close to the original data points. If the bin size is too coarse, it will cover up any nuance with just a few buckets and flattens the distribution.
#
# For the data distribution, I like the bin size of 0.5 for revealing the most significant features of the data set, as it shows that the data is approximately normally distributed, but it also shows the interesting drop on the right hand side of the histogram, between 13 and 14.
#
# The bin size has no impact on the mean and median of the data set, these are static values that are based on our sample data and are not impacted by how the data is displayed.
#
# Our mean and median values are fairly close together, but the mean is greater than the median, which means that our data set is positively skewed, or right-skewed.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## 🔖 **$\color{blue}{\textbf{Lab Work 4:}}$ Analyze Centrel Tendancy of data in Pandas DataFrame**

# %% [markdown]
# ### **pandas syntax**

# %% [markdown]
# > #### **Calculating `mean` and `median`**
#  ```
#  dataframe.mean(axis = 0, skipna = True, numeric_only = None)
#  dataframe.median(axis, skipna, level, numeric_only, kwargs)```
# <details>
#   <summary><b>Show explanation of parameters</b></summary>
#
# **axis:** "index or 0" or "column or 1" \
# **skipna:** Optional, "True" or "False", default True. \
# **numeric_only:**	Optional, "None", "True", "False", Default NoneSpecify whether to only check numeric values.
# **return:** A Series with the mean values.
# </details>
#
# > #### **Calculating mode**
#
#  ```
#  dataframe.mode(axis, dropna = True, numeric_only, kwargs)
#  ```
# <details>
#   <summary><b>Show explanation of parameters</b></summary>
#
#  **axis:** "index or 0" or "column or 1" \
# **dropna:** Optional, "True" or "False", default True. \
# **numeric_only:**	Optional, "True", "False", Default False, Specify whether to only check numeric values. \
# **return:** A Series with the highest frequency value in a  (column).
# </details>

# %% [markdown]
# ### **1.** Import the [raw data](https://raw.githubusercontent.com/fivethirtyeight/data/master/fandango/fandango_scrape.csv) into a pandas data frame.

# %%
movie_data = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/fandango/fandango_scrape.csv")
movie_data.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %% [markdown]
# ### **2.** Compute mean, median and mode and other statistics of `RATING` or `STARS`, or "VOTES"
# >##### **Note:** The mean could be more than 9 decimal places so use the `f-string` format to keeo only 1 decimal place.  For example, if you used `rating_mean` for mean rating, your `f-string` should be `f"mean rating = {rating_mean: .1f}"`

# %%
# Note that for more recent versions of Pandas, `numeric_only` defaults to False
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html
movie_data.mean(numeric_only=True)
movie_data.median(numeric_only=True)
movie_data.mode(numeric_only=True)
# Out:
#    STARS  RATING  VOTES
# 0    4.0     0.0      0

# %%
movie_data.mode()
# Out:
#                FILM  STARS  RATING  VOTES
# 0  Nannbenda (2015)    4.0     0.0      0

# %%
print(f"The mean of the ratings is: {movie_data.RATING.mean(): .1f}")
print(f"The median of the ratings is: {movie_data.RATING.median()}")
print(f"The mode of the ratings is: {movie_data.RATING.mode()}")

print(f"The mean of the votes is: {movie_data.VOTES.mean(): .0f}")
print(f"The median of the ratings is: {movie_data.VOTES.median()}")
print(f"The mode of the ratings is: {movie_data.VOTES.mode()}")

print(f"The maximum number of votes for a film is: {max(movie_data.VOTES)}")
# Out:
# The mean of the ratings is:  3.4
# The median of the ratings is: 3.8
# The mode of the ratings is: 0    0.0
# Name: RATING, dtype: float64
# The mean of the votes is:  1134
# The median of the ratings is: 17.5
# The mode of the ratings is: 0    0
# Name: VOTES, dtype: int64
# The maximum number of votes for a film is: 34846

# %% [markdown]
# ### **3.** Plot a static histogram of the `RATING` and a vertical line to represent the mean.
# > * Label the plot and vertical line.
#
# >* Adjust the size of the plot, set the appropriate graph title and choose the position of the legend.

# %%
plt.Figure(figsize=(15, 7))
# Histogram
movie_data.RATING.plot.hist(bins=50)
#plt.hist(movie_data.RATING, label="Movie Ratings")
plt.xlabel("Movie Ratings")
plt.ylabel("Count")

plt.axvline(movie_data.RATING.mean(), linestyle="--", linewidth=2, color="orange", label=f"Mean Rating: {movie_data.RATING.mean(): .1f}")
plt.axvline(movie_data.RATING.median(), linestyle=":", linewidth=2, color="red", label=f"Median Rating: {movie_data.RATING.median(): .1f}")

plt.legend(
    loc="upper right",
    bbox_to_anchor=[1.50, 1],
    shadow=True,
    fontsize="medium"
)
plt.title("Rating Distribution of Movies")
plt.show()

# %% [markdown]
# > * #### How are the mean and median related in the data set?
# >> #### The mean and median are the same.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **$\color{green}{\textbf{TODO 3: }}$ Analyze Centrel Tendancy of of [the iris dataset](https://docs.google.com/spreadsheets/d/1mpaQoG1IcaMBG-yKYR-2L0JtgMw0DIqVQjeHnP9qSgo/edit?usp=sharing).**

# %% [markdown]
# ### **1.** Import the [the iris dataset](https://docs.google.com/spreadsheets/d/1mpaQoG1IcaMBG-yKYR-2L0JtgMw0DIqVQjeHnP9qSgo/edit?usp=sharing) into a pandas data frame.

# %% [markdown]
# **Syntax for creating an url for reading a .cvs file into data frame**
#
# ```python
# import pandas as pd
#
# sheet_url = "https://docs.google.com/spreadsheets/d/1mpaQoG1IcaMBG-yKYR-2L0JtgMw0DIqVQjeHnP9qSgo/edit#gid=0"
# url = sheet_url.replace("/edit#gid=", "/export?format=csv&grid=")
# ```

# %%
import pandas as pd

sheet_url = "https://docs.google.com/spreadsheets/d/1mpaQoG1IcaMBG-yKYR-2L0JtgMw0DIqVQjeHnP9qSgo/edit#gid=0"
url = sheet_url.replace("/edit#gid=", "/export?format=csv&grid=")
iris_df = pd.read_csv(url)
iris_df.head()
# Out:
#    Index  sepal.length  sepal.width  petal.length  petal.width      species
# 0    1.0           5.1          3.5           1.4          0.2  Iris-setosa
# 1    2.0           4.9          3.0           1.4          0.2  Iris-setosa
# 2    3.0           4.7          3.2           1.3          0.2  Iris-setosa
# 3    4.0           4.6          3.1           1.5          0.2  Iris-setosa
# 4    5.0           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### **2.** Compute the mean, median , and mode of `sepal.length`, `sepal.width`,  `petal.length`, or `petal.width`
# > **Note:** The mean could be more than 9 decimal places so use the `f-string` format to keeo only 1 decimal place.  For example, if you used `sepal_width_mean` for mean sepal width, your `f-string` should be `f"mean sepal width = {sepal_width_mean: .1f}"`

# %%
iris_means = iris_df.mean(numeric_only=True)
iris_medians = iris_df.median(numeric_only=True)
iris_modes = iris_df["sepal.length"].mode()
print(f"The mean of sepal.length is: {iris_means['sepal.length']: .1f}")
print(f"The median of sepal.length is: {iris_medians['sepal.length']: .1f}")
print(f"The mode(s) of sepal.length are: {iris_modes.tolist()}")
# Out:
# The mean of sepal.length is:  6.0
# The median of sepal.length is:  6.1
# The mode(s) of sepal.length are: [5.0, 6.3]

# %% [markdown]
# ### **3.** Plot a static histogram of the `RATING` and a vertical line to represent the mean.
# > * Label the plot and vertical line.
#
# >* Adjust the size of the plot, set the appropriate graph title and choose the position of the legend.

# %%
iris_df["sepal.length"].plot.hist(bins=20)
#plt.hist(movie_data.RATING, label="Movie Ratings")
plt.xlabel("Sepal Lengths")
plt.ylabel("Count")

plt.axvline(iris_means["sepal.length"], linestyle="--", linewidth=2, color="orange", label=f"Mean Sepal Length: {iris_means['sepal.length']: .1f}")

plt.legend(
    loc="upper right",
    bbox_to_anchor=[1.50, 1],
    shadow=True,
    fontsize="medium"
)
plt.title("Distribution of Sepal Lengths")
plt.show()
