# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # $$🌈\textbf{ PostLab TODOs for LAB 1 - 1 Python Basic  } 🌙$$
# ## **<font color = "red">These are the same TODOs </font>as in the Corresponding LAB**
# ## ✍ **Complete all questions in each of the $\color{green}{\textbf{TODOs}}$ from the LAB.**
# ### **1.** Click ▶ to view the problem detail
# ### **2.** Refer to the code you learned from Lessons with Code and LABs.
# ### **3.** Always use **`f-string`** to print out the results for each problem.
# ### **4.** Plots should include a title and labels for the x and y axes.
# #### $\color{magenta}{\textbf{ NOTE: }}$ It is strongly recommended that you need to understand the relevant concepts and learn the necessary statistical programming for computation with Python taught in the video lessons or labs and have completed the worksheets for the lessons and Lab before attempting the TODOs.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## **Variable Container for Users Input**
#   We often enter information on a form.  Sometimes we want to know that information the form contains.  Other times we might want to hide the inforamtion.  Take a lok at the code below.  If the code does not make sense to you, run it to see if it does.

# %% [markdown]
# The line <code>name = input("What's your name?")</code> works like the other variable container statements we've seen efore.  It puts the value ofthe thing on the right input("What's your name?"), into the variable container on the left - in this case name.
#
# <code>input(..)</code> is called a Python function, which is a very important object in all computer language.  <code>*Functions*</code> are ways to run separate sections of code.
#
# The string in parehtheses in input("Question"), is the text the computer will use to prompt the user.  Notice now, in the code above, putting "What's your name?" inside the paentheses caused the Python to ask you for your name.

# %% [markdown]
# ###🧚 **$\color{orange}{\textbf{Review:}}$ Coding Hints** ```fstring```
#
# ```f"... string ... {variable} ... string ..."```
#
# Combine strings and variables in one print statement by enclusing each variable between { and }

# %%
name =input("What's your name?")
noClass = 4
print(f"Hi {name}! Nice to meet you.  I am taking {noClass} classes this semester.")
# Out:
# What's your name?Tim
# Hi Tim! Nice to meet you.  I am taking 4 classes this semester.

# %% [markdown]
# ###**$\color{green}{\textbf{TO DO 1:}}$**.
# Write three lines of code below.
# 1. Ask the user for his name and same the answer in a variable container called name.
# 2. Ask the user for his or her favorite number, and same the answer in a variable contained called <code>num</code>.
# 3. Print the following output. Hi there, " your name"!  The double of my favorite number  is ____.  For example, if the favorite number is 28, you should print 56.  ($\color{red}{\text{Hint:}}$ the function <code> int() </code> turns a number from a string to a number. That way, you can multiply <code>int(num)</code> by 2 to double the value.

# %%
name = input("What is your name?")
num = int(input("What is your favorite number?"))
print(f"Hi there, {name}! The double of my favorite number is {num * 2}")
# Out:
# What is your name?Tim
# What is your favorite number?4
# Hi there, Tim! The double of my favorite number is 8

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Python Objects: Strings (Type ```str```)**
# Computer scientists have a special word for text: $\color{red}{\text{strings}}$. It's an old term – dating back to printing presses in the late 1890s! – that came about because all words are made up of letters that have been "strung together."
#
# Anything can be a string when programming, just like anything can become text when you're typing.

# %% [markdown]
# ###**$\color{green}{\textbf{TO DO 2:}}$** Write codes to print your name, major, and today's date on three separate lines.

# %%
print("Tim Sanders")
print("Computer Science/Statistics/Math")
print("February 24, 2025")
# Out:
# Tim Sanders
# Computer Science/Statistics/Math
# February 24, 2025

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##**Formated String Literals```f-string```**
#
# f-string literal denoted with a *f* before the quotes can evaluate *expression* placed within braces { }, including referneces to variables, function calls and comparison.  We will use ```f-string``` mostly in our statistics course.

# %% [markdown]
# ###**$\color{green}{\textbf{TO DO 3:}}$**
#
# define two variable one for your height in feet and the other in inches.
#
# Print the following statement using f-string and variables you defined My height is ___ feet and ___ inches.

# %%
height_in_feet = 5
height_in_inches = 9
print(f"My height is {height_in_feet} feet and {height_in_inches} inches.")
# Out:
# My height is 5 feet and 9 inches.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Comparison Operators**
#
# Boolean expression are logic expressions with operators, similar to the mathematical expressions with arithmetic operators.  Boolearn operators and their meaning are:
#
# *   $\color{blue}{>}$: greater than
# *   $\color{blue}{<}$: less than
# *   $\color{blue}{>=}$: greater than or equal to
# *   $\color{blue}{<=}$: less than or equal to
# *   $\color{blue}{==}$: equivalent$\hspace{28mm}\color{blue}{\text{NOTE}}$:  Not equal but equivalent
# *   $\color{blue}{!=}$: not equivalent        $\hspace{20mm}\color{blue}{\text{NOTE}}$:  Not equal but equivalent

# %%
2 + 5 >= 4
# Out:
# True

# %%
(2 + 5) >= 4
# Out:
# True

# %% [markdown]
# ###**$\color{green}{\textbf{TO DO 4:}}$**  Create four boolean expressions in Python using the boolean operators
#
# 1.   A boolean expression that includes the "greater than" symbol and returns  $\color{blue}{\text{False}}$
# 2.   A boolean expression that includes the "less than" symbol and returns  $\color{blue}{\text{False}}$
# 3.   A boolean expression that includes the "equivalent" symbol and returns  $\color{blue}{\text{False}}$
# 4.   A boolean expression that includes the "not equivalent" symbol and returns  $\color{blue}{\text{True}}$

# %%
# TO DO 4.1
4 > 5
# Out:
# False

# %%
# TO DO 4.2
65 < 5
# Out:
# False

# %%
# TO DO 4.3
"Tim" == "Danielle"
# Out:
# False

# %%
# TO DO 4.4
3 != "three"
# Out:
# True

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Logic Operators**
# Just as we need to combine arithmetic operations to create a complext mathematical expression, we often need to deal with more than one logical expressions including more than one boolean opearators.
#
# Python reserves three keywords "$\color{blue}{\text{and}}$," "$\color{blue}{\text{or}}$," $\color{blue}{\text{not}}$ "to help us strining together the logic operators.  The resultant value can be found in the Truth Table below
#
# <details>
#   <summary><b>Truth Table</b> </summary>
#
#   | $p$  |  $q$  | $p$ and $q$|$p$ or $q$ |not $p$
# |:----:|:-------:|:-----:|:--:|:--:|
# | $T$  |  $T$  | $T$| $T$|$F$ |
# | $T$  | $F$ |$F$| $T$|$F$
# | $F$|  $T$|$F$| $T$|$T$ |
# |$F$  |  $F$  | $F$| $F$|$T$ |
#
# </details>

# %% [markdown]
# ###🧚 **$\color{orange}{\textbf{Tip:}}$  Parathesis are important when we combine boolean expressions.*8

# %%
True and False
# Out:
# False

# %%
2 > 0 and 4949 < 48
# Out:
# False

# %%
not False                # without parenthesis
# Out:
# True

# %%
not (False)              # with parenthesis
# Out:
# True

# %%
not True and False         # without parenthesis
# Out:
# False

# %%
not (True and False)       # with parenthesis.  Are you surprised
# Out:
# True

# %%
2 > 0 or 4949 < 48
# Out:
# True

# %%
not 2 < 0 or 4949 > 48        # without parenthesis
# Out:
# True

# %%
not (2 < 0 or 4949 > 48)      # with parenthesis
# Out:
# False

# %% [markdown]
# ###**$\color{green}{\textbf{TO DO 5:}}$** Challenge
#
# 1. Write a python code for a boolean expression that includes the "greater than or equal to" symbol and returns  $\color{blue}{\text{True}}$
#
# 2.   Write a python code for a boolean expression that includes the "less than or equal to" symbol and returns  $\color{blue}{\text{True}}$
#
# 3.   What would be the outcome for this logic expression. 4 + 4 > 2 and 4 != 5?
#
# 4.   Write code using "not," "4 + 4 > 2 and 4 != 5" with outcome = $\color{blue}{\text{True}}$. (Hint: use parathesis)
#
# 5.   Write code using "not," "4 + 4 > 2 and 4 != 5" with outcome = $\color{blue}{\text{False}}$.

# %%
# TO DO 5.1
4 >= 3
# Out:
# True

# %%
# TO DO 5.2
3 <= 100
# Out:
# True

# %%
# TO DO 5.3
# 4 + 4 > 2 and 4 != 5
# This expression evaluates to True
4 + 4 > 2 and 4 != 5
# Out:
# True

# %%
# TO DO 5.4
not (not (4 + 4 > 2 and 4 != 5))
# Out:
# True

# %%
# TO DO 5.5
not (4 + 4 > 2 and 4 != 5)
# Out:
# False
