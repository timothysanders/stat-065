# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # $$🌈\textbf{ PostLab 2.2 Simple Random Sampling  } 🌙$$
# ### **<font color = "red">These are the same TODOs </font>as in the Corresponding LAB**
# ### ✍ **Complete all questions in each of the $\color{green}{\textbf{TODOs}}$ from the LAB.**
# #### **1.** Click ▶ to view the problem detail
# #### **2.** Refer to the code you learned from Lessons with Code and LABs.
# #### **3.** Always use **`f-string`** to print out the results for each problem.
# #### **4.** Plots should include a title and labels for the x and y axes.
# #### $\color{magenta}{\textbf{ NOTE: }}$ It is strongly recommended that you need to understand the relevant concepts and learn the necessary statistical programming for computation with Python taught in the video lessons or labs and have completed the worksheets for the lessons and Lab before attempting the TODOs.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **Simple Random Sampling from a Population as a list of names**

# %% [markdown]
# ---
# ### 🧚 **$\color{green}{\textbf{TO DO 1:}}$ Follow the example above to do the following**

# %% [markdown]
# #### **1. Create a modified population from the class roster above**
# * Add a code cell below
# * Copy and past the list above to the code cell.
# * Add three new names of your choices to the population.
#
# $\color{red}{\text{Make sure that you use the correct syntax following the example}}$

# %%
import numpy as np

population = [
    "Anselmo", "Bautista", "Bayani", "cheng", "Cuarismo", "Cuningham", "Fontecha", "Hong", "Hoobler","Jiao",
    "Khan", "King", "Legeny", "Lundquist", "Macierz", "Motogawa", "Okimoto", "patel", "Price", "Quizon", "Reyes",
    "Roquero", "Roth", " Rowell", "Salangsang", "Slade", "Stratcher", "Tallar", "Tran","Wai", "Wood",
    # Add new names
    "Miles", "Mae", "Misty", "Tim", "Danielle"
]

# %% [markdown]
# ####**2. Create one sample with 7 names ramdomly selected from the population without replacement.**
# **Run your code to see the output**

# %%
random_names_no_replacement = np.random.choice(population, 7, replace=False)
print(f"Sample with seven names selected without replacement: {random_names_no_replacement}")
# Out:
# Sample with seven names selected without replacement: ['Cuningham' 'Tim' 'Stratcher' 'Danielle' 'Khan' 'Quizon' 'Anselmo']

# %% [markdown]
# ####**3. Create one sample with 4 names ramdomly selected from the population with replacement.**
# $\color{red}{\text{Run your code repeatedly until the outcome shows at least one duplicated name in your sample.}}$

# %%
random_names_replacement = np.random.choice(population, 4, replace=True)
print(f"Sample with four names selected with replacement: {random_names_replacement}")
# Out:
# Sample with four names selected with replacement: ['Quizon' 'Macierz' 'Macierz' 'King']

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **Simple Random Sampling from a Population as a list of random numbers**

# %% [markdown]
# ## **Syntax for generating random numbers**
# ### **Code Structure:** $\hspace{20mm}$ ```numpy.random.```$\color{blue}{\text{source}}( \color{magenta}{\text{parameters}})$

# %% [markdown]
# |functionality| $\color{blue}{\textbf{Souces syntax }}$($\color{magenta}{\textbf{parameters }}$)| outputs|
# |--|--|--|
# |A Range of Numbers | ```randint(low, high, size, dtype)``` |Return random integers from low (inclusive) to high(exclusive), <br> or if endpoint=True, low (inclusive) to high (inclusive)|
# |  | ```random(size)```|Return random floats in the half-open interval [0.0, 1.0)|
# | | ```randn(d0, d1, ...)```|Return a given shape filled with random floats from a standard normal distribution|
# | | ```rand(d0, d1, ...)```|Return a given shape filled with

# %% [markdown]
# ## 🧚 **$\color{green}{\textbf{TO DO 2:}}$ Follow the example above to do the following**

# %% [markdown]
# #### **1.** Define a variable ```population_int``` with a population of 100,000 integers between 0 and 5000.

# %%
population_int = np.random.randint(low=0, high=5000, size=100000)
print(f"The size of the variable `population_int` is: {len(population_int)}")
# Out:
# The size of the variable `population_int` is: 100000

# %% [markdown]
# #### **2.** Creating a Sample Using simple random sampling with replacement
# * Define a variable ```sample1``` of size 3000 integers via simple random sampling from the population_int **with** replacement.
# * Use `f-string` to print out the `sample1` with description as that in the example above

# %%
sample1 = np.random.choice(population_int, size=3000, replace=True)
print(f"The results of the random sample with replacement are: {sample1}")
# Out:
# The results of the random sample with replacement are: [2956 3939 1513 ... 1221 3852 4272]

# %% [markdown]
# #### **3.** Creating a Sample Using simple random sampling without replacement
# * Define a variable ```sample2``` of size 500 integers via simple random sampling from the population_int with ** without** replacement,
# * Use `f-string` to print out the `sample2` with description as that in the example above

# %%
sample2 = np.random.choice(population_int, size=500, replace=False)
print(f"The results of the random sample without replacement are: {sample2}")
# Out:
# The results of the random sample without replacement are: [ 221 4976 1754 1695  710 2437 1738 3775  912  865 3095 2797 2325  916
#  1815 3657  110 2295 1520 3215 2117 4817 2870 4359  396  636 1002 1697
#   339 1791  590 4577  217 1917 1662 1719  535 1671 1565 1257 2231 2433
#  4741 2018 3869 2248  690 4125 3093  525 4733  597  346  370 4187 2061
#  2540 4178  985 4488 4315   18 2236  978 2577 3155 3183 3340 3640 4530
#  4660   62 2873 1982 4324 1855 2555   73 2835 3633   63 3146 2184 4970
#  4590 2043 1083 1800 2782 3894  721 2425 1849  426  993  308 1570  582
#  4257 1874 2124 3646 3765 2671 2950 1836 1175  688 2179 2886 3977 4835
#  3550  561 1057 1367 2823  429 1884 4096 3565 1883 1947 2993 4947  765
#  2727 3179 2497  567  337 1875 3593 3463 1100 1486 2730  506 4694  256
#  3132 1572 3300 1227 2402 3029 1795 1904 2042 2884 2390 2060 4826  837
#  1746 4401 4150 1380 2605 1696  848 2249 2057 3106 2833 4963 3213 2721
#  2160 2199 4555 1888  824 2835  970 4172 2321 2931 2349 1842  372 2831
#   295 2407  951  451 2310 4055 3469 3162  867 1764 3722 4993 1702 3165
#   614   47 4659 4086 4381 3841 3926 1201 4370 4066 3722 1132  670 1150
#   149 4485 2792  606 4494 1507 4724 4557 1085 3513 2956 4111 3758 3862
#  4409 4716 3676 2431 2704  290 1173  193 3188 4671 1380 1133 4263 3983
#  1984 2886 2331 1950 2966 1333 3265 1481 2758 1826 1224 4579 1871  306
#  4912 2547 3306 4498 4565 1746 4290 3287 3711 2403 4499 4172  330 2406
#  4543 1551 4627 1759 3236 1709  486 2243 2223   66  991 3533  566 3047
#  2760   50 3468 2543 4915 4841 4094   50  520 2850 2254 4817 4627 4304
#   550 3378  498  222 3316 1117 3101 3990 3490  789 1917 4297 4562 1367
#  2263 2090  194 1578 1285  174 4166 4520 3766 2025 4751 1711 4012 1589
#  1376  521 4921 2971 3792 1990 1395 2544 4819 3591 4071 1841 3082 2401
#  4768 3937 2747 3553 1242 3067  740 1325 1877  187 4864 2706 3501 2874
#   281 1583 2540  542 4990 2515 2360 1965  982 3644 2035 1882  709 2583
#  1700 4835 4254 3776 4276 4645  261 4392 2176  362 2293  799 4443  345
#   282  827 1953 1631 2698 2159 3185 4070 4658 1728 1083  585 1540 3005
#  1678 4246 1373  449 1142 2667  949 4950 1877 2420  236  556  673  822
#   557  938 3763 1232   52 3092  128  304 2712 3819  650 1619  394 2478
#  2170  172 3808 4089 1720 2709 2728  726 1575 1756 3209 1704 3276 1200
#  4448 4096 4892 3041 2745 3499 3527 1959  856 1281 1466 4835 2026 3165
#  3362  994 3930 3573 4594 2650  528 4055 3988 2987  860 3762 1218 1749
#  4340 3042  713 3972 1846 2024 1400 2729 4741 3554 4878 2417 2592 3768
#  1983  440  202 4902  754 2369 3661   80 3563 4203 1937 2272 2203 2177
#  3152 1677 1616 3679 1882 3245   13 2199 1711 1609]
