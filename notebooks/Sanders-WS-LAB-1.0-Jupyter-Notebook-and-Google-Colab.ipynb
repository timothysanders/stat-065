# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# # **$$🔶 \textbf{   Software is a Lab Equipment for the 21st Century   }🔶$$**

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # 📔 **Jupyter Notebook**
#
# From the official Webpage [jupyter.org](https://jupyter.org/)
#
# > The Jupyter Notebook is a web application that allows you to create and share documents that contain *live code, equations, visualizations,* and *explanatory text.*
#
#
# * to create a blank Jupyter Notebook click
#  [here](https://colab.research.google.com)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##$$\textbf{Like everything in a} \color{blue}{\textbf{ line notebook }} \textbf{is a }\color{red}{\textbf{line}} \\ \textbf{Everything in a} \color{blue}{\textbf{ Jupyter notebook }} \textbf{is a}\color{red}{\textbf{ cell}}$$
#
# ---
#
# ### **$$Text \text{ or } Code \color{red}{\textbf{ cell}}$$**
# ---
# ## $\hspace{70mm}$Hit `SHIFT+ENTER` to execute the contents of a cell

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **UNDO**
#
# ### **😒 To undo delete a cell or an inserted cell:** Go to Edit in the menu bar
# ### **😒 To undo code or mark down text:** use `command + z` or `control + z` in the same cell where the code and text deleted.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **SAVE**
#
# ### **Auto Save:** Google Colab save Jupyter Notebook automatically by default.
# ### **Manual Save:** Go to File in the menu bar
#
# ### **❗⚠❗ Not Saved:** If you have the **same Jupyter Notebook** open on two **separate computers** or as tabs, there will be occasions when the code does not save, so it is important to ensure that the code is saved in each location, and checked to ensure it has been updated in each location the program has been moved to.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Images**
#
# <p style="text-align:center;"><img src = "https://drive.google.com/uc?id=1U_u97PZNWTLCWUME33obwbc_97uHDFuW" alt="" width = "300px" height = "300px" />
#
# Or hide the image until you need to use it
# <details>
#   <summary><b>Show an image from google drive</b></summary>
#
# <p style="text-align:center;"><img src = "https://drive.google.com/uc?id=1U_u97PZNWTLCWUME33obwbc_97uHDFuW" width = "300px" height = "300px" />
# </details>
#
# Watch this [video](https://www.3cmediasolutions.org/privid/388761?key=80917d5390fd86322a2160cb3e2ca310a0d7c5b5) on how to create a link in Markdown to an image on Google Drive.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ##**Text Cells**
#
# Text cells (like this one) can be edited by double-clicking on them. They're written in a simple format called [Markdown](https://daringfireball.net/projects/markdown/syntax) to add formatting and section headings. You don't need to learn Markdown, but you might want to.
#
# After you edit a text cell, click the "run cell" button at the top that looks like ▶| or hold down ```shift``` + ```return``` to confirm any changes. (Try not to delete the instructions of the lab.)
#
# [Cheat-sheet](https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Cheat_sheet_for_Google_Colab.ipynb) for markdown in Colab

# %% [markdown]
# ###🔖 **$\color{blue}{\textbf{Practice: }}$ Use Markdown cell Text Editor**
# ### $\hspace{40mm}$ **👉 Double click on me 👈** or Hit `ENTER` to open a markdown cell for editing
#
# If you're seeing those asterisks "** **," it's because you've correctly entered "Edit Mode".

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## 🔖 **Inline and Display mode of mathematics with Latex**
# LaTeX is a typesetting language for producing scientific documents. We introduce a very small part of the language for writing mathematical notation. Jupyter notebook recognizes LaTeX code written in markdown cells and renders the symbols in the browser.
#
# **There many resouces for Latex.  Here are three:**
# * [mathematicas](https://en.wikibooks.org/wiki/LaTeX/Mathematics) of LaTex WikiBook and
# * [How to write matrices in Latex: Step by Step](https://www.physicsread.com/latex-matrix/) by Jidan.
# * Cheat-sheet of [Latex Math for Undergrduates](https://tug.ctan.org/info/undergradmath/undergradmath.pdf)

# %% [markdown]
# ## 🔖 **$\color{blue}{\textbf{Practice:}}$ Write inline Math formula in Latex using the fork icon or "\\"**

# %% [markdown]
# $\frac{4!}{3!}$

# %% [markdown]
# ###**$\color{green}{\textbf{TO DO:}}$**
# #### Write in latex a quadratic function or other math formula in both inline and display math modes.  If you first type out the 4 dolloar signs and enter latex code, you should see the rendered latex code in real time.
#
# $y = x^2 - x - 1$
#
# $$y = x^2 - x - 1$$

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # **Code Cell: Instructions to the Computers**
# ###Output is displayed below the code cell
#
# Other cells contain code in the Python 3 or other langauge. Running a code cell will execute all of the code it contains.
#
# To **run** the code in a code cell, first click on that cell to activate it. It'll be highlighted with a little green or blue rectangle. Next, either press ▶| or hold down ```shift``` + ```return```.

# %%
5 +1
# Out:
# 6

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## 🔖 **$\color{blue}{\textbf{Practice:}}$ Create a Keyboard Shortcuts table**

# %% [markdown]
# | Key combination | Description |
# |-----------------|-------------|
# | shift + enter   | run cell    |
# | command + z     | undo        |
# | command + a     | select all  |
# | command + x     | cut         |
# | command + c     | copy        |
# | command + v     | paste       |

# %% [markdown]
# ###**$\color{green}{\textbf{TO DO:}}$ inserting a code cell:** Click "+code" button on top or bottom of this text cell or use the keyboard shortcut "b" to insert a code cell below to practice Writing Strings in Python.
# ### Strings are enclosed between a set of **single or double quotes.**

# %%
"This is a string in Python"
# Out:
# 'This is a string in Python'

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # **Python Syntax**
# ###🧚 **$\color{orange}{\textbf{Tip:}}$ $\color{magenta}{\text{Do not attempt to memorize anything.}}$**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Execute Python Syntax and Read Error Messages**
# Python syntax can be executed by writing directly in the code cell:

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Python Indentation**
# ### Indentation refers to the spaces at the beginning of a code line.
#
# #### Where in other programming languages the indentation in code is for readability only, the indentation in Python is **very important.**
#
# ### 🥦 **$\color{red}{\text{Python}}$** uses indentation to indicate **$\color{red}{\text{a block of code}}.$**

# %% [markdown]
# ---
# ### 🔖 **$\color{blue}{\textbf{Practice:}}$ Customize your code display inlcluding indentation**
# * Insert a code cell
# * Click the "gear" (the setting icon) on the menu bar above in the upper right corner
# * Choose "Show indentation guide" for each "tab" key press.
# * The "Line number" refers to the code in "each cell."
# * Choose others you prefer.  You can always modify the setting.

# %% [markdown]
# ---
# ### 🔖 **$\color{blue}{\textbf{Practice:}}$ Create an example of a code block using indentation**

# %%
x = 1
while x < 10:
    print(x)
    x += 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# ---
# #### 🔖 **$\color{blue}{\textbf{Practice:}}$ error message when writing a code block without indentation.** $\color{red}{\text{IndentationError:}}$ `expected an indented block`
# * Insert a code cell below
# * Copy/paste the if statement in the code cell
# * Remove the indentation of the print statement
# * Run the code cell.

# %%
if x == 1:
print("yes")
# Out:
#   File "<ipython-input-5-baae7db979bf>", line 2
#     print("yes")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# ---
# #### 🔖 **$\color{blue}{\textbf{Practice:}}$ Number of spaces for indentations:**. The number of spaces is up to you as a programmer, the most common use is **four**, but it has to be **at least one.**

# %%
x = 1
if x == 1:
 print("correct")
else:
 print("incorrect")
# Out:
# correct

# %% [markdown]
# ---
# #### 🔖 **$\color{blue}{\textbf{Practice:}}$ Error message of different indentation within the same block code**. You have to use **the same number of spaces in the same block of code**, otherwise Python will give you an error: $\color{red}{\text{IndentationError:}}$ `unexpected indent`

# %%
x = 1
if x == 1:
  print("correct")
    x += 1
else:
    print("incorrect")
# Out:
#   File "<ipython-input-10-136fa46d7d07>", line 4
#     x += 1
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Python Assignment Operators**
#
# > Operators are used to perform operations on values and variables. These are the special symbols that carry out arithmetic, logical, bitwise computations. The value the operator operates on is known as **Operand.**
#
# Assignment Operators are used to assigning values to variables.
#
# | Operator|Description|Syntax|
# |--|--|--|
# |`=`| Assign value of **right** side of expression **to left** side operand| `x = y + z`|

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##**Python White Space**
#
# Whitespace is a string that has been pre-initialized and is used as a string constant. Whitespace is simply a character that is used for spacing and has an "empty" representation.  It refers to tabs and spaces in the contenct of Python.

# %% [markdown]
# #### 🔖 **A list of commonly used *white space*** for "empty" representation

# %% [markdown]
# 1. ' ' - Space
# 2. '\n'- Newline
# 3. '\r'- Carriage return
# 4. '\t'- Horizontal tab
# 5. '\v'- Vertical tab

# %% [markdown]
# ---
# #### 🔖 **$\color{blue}{\textbf{Practice:}}$ Use** `isspace()` function to check if a string is a white space.

# %%
x = " "
x.isspace()
# Out:
# True

# %% [markdown]
# ---
# ###🧚 **$\color{orange}{\textbf{readibility:}}$ Use $\color{magenta}{\text{ one whitespace to separate }} $expressions, operators, and variables to increase code readibility.**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## 🍵 **Good Practice: 10x more productive than average**
#
# Scientists spend a lot of time writing it but since it is new and not taught in college, over 90% are self-taught so they don't know what "good" look looks like.

# %% [markdown]
# ###🔖 **Describe General Rules for Good Programming Practice**

# %% [markdown]
# <details>
#   <summary><b>Show Descriptions of Rules for Good Practices</b></summary>
#
# ### **1. Write program for people and not computers**
# >#### **1a.** A program should not require its readers to hold more than a handful of facts in memory at once.
#   * Short-term memory can hold 7±2 items
#   * So break programs into short, readable functions, each taking only a few parameters.
#
# >#### **1b.** Make names consistent, distinctive, and meaningful.
#   * $p$ does not help reader's short term memory as much as pressure
#
# >#### **1c.** Make code style and formatting consistent.
#
# ### **2.** Let the Computer Do the Work
# * 99% accuracy ⇒ 63% of at least one error per hundred repetitions
# * Make the computer repeat tasks
# * Write little programs for everything
#
# ### **3.** Make incremental changes
#
# ### **4.** Reuse the Code Instead of Rewriting It
# ### **5.** Plan for Mistakes
# ### **6.** Optimize Software only after It Works correctly
# ### **7.** Document Designs and Purpose and Not Mechanics
# ### **8.** Collarboarte
# * Computers were invented to calculate
# * The web was invented to collaborate
# * Science is more fun when it's shared
# </details>

# %% [markdown]
# ###🔖 **$\color{blue}{\textbf{Practice: }}$ Write requirements for Submission  of homework in Jupyter Notebooks**

# %% [markdown]
# 1. **Save** a copy in your Google Drive. (Go to "File" on the menu bar)
#   - Use the [resource](https://www.tutorialspoint.com/google_colab/google_colab_saving_work.htm) if you need more help saving Jupyter Notebook to your Google Drive.
# 2. **Modify** the name of the file. (Directly in the title text)
# 3. **Save** your work:
#   - Google saves every version of your Jupyter Notebooks
#   - The autosave of the Jupyter Notebook is on as long as you have only one of the same Jupyter Notebook open (Google allows multiple openings of the same file).
#   - To save your work manually, go to "File" on the menu bar.
# 4. **Move** the file to your desired folder (Use "Move To" under "File" on the menu bar)
# 5. **Share** [your work](https://www.tutorialspoint.com/google_colab/google_colab_sharing_notebook.htm)
#   - Click on the SHARE link at the top right-hand corner of your Colab notebook. This will open the share box.
#   - You can enter the email IDs of the people you want to share the document with. You can set the kind of access by selecting from the available options shown in the sharing window.
#   - Click on the Get Shareable link option to get the URL of your notebook.
# 6. **Submit Jupyter Notebook**
#   - Set the "share option" of the Jupyter Notebook to "Pasadena City College"  by clicking the "Share" on the upper right corner of your Jupyter Notebook.
#   - Click on the "copy link" button.
#   - Submit the copied link to Canvas by pasting it to the box labeled "Website URL:."

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **What is Statistical, Scientific, and Mathematical Programming?**
#
# **Python Libraries and Jupyter Notebooks are used exclusively**

# %% [markdown]
# <details>
#   <summary><b>About Python Libraries</b></summary>
#
# **1. What are Python libraries?**
#
# Python libraries are a collection of related modules that contain bundles of codes that can be used in different programs. Python libraries make it convenient for the programmer as they wouldn’t have to write the same code multiple times for different programs. Some common libraries are OpenCV, Apache Spark, TensorFlow, NumPy, etc.
#
# **2. How many libraries are in Python?**
#
# There are over 137,000 Python libraries available today. These libraries can help create applications in machine learning, data science, data manipulation, data visualization, etc.
#
# 3. Which library is most used in Python? **bold text**
#
# Numpy is the most used and popular library in Python.

# %% [markdown]
# ---
# ### **Comprehensive Lists of Python Libraries**
# [PyPi](https://pypi.python.org/pypi?%3Aaction=index) is the primary source for Python packages and they have an index.  These are the packages you can install with pip or easy_install.
#
# However given that there are ~45k packages on PyPi, general browsing is not going to be of much help.
#
# Also there are more libraries that are hosted on places like Github, Bitbucket etc and are not present on PyPi. So you can also search there.

# %% [markdown]
# ---
# ### **Scientific Libraries**
#
# Over [40 popular Scientific Python libraries](https://www.stxnext.com/blog/most-popular-python-scientific-libraries/) and we will use mostly for the following in this statisstics course

# %% [markdown]
# ###🔖 **Libraries used in PCC STAT 065 and STAT 050**
#
# * `NumPy` for numerical computation, matrices, and random numbers
# * `SymPy` for symbolic algebrain Math
# * `matplotlib`, `seaborne`, and `plotly` for visualization
# * `Scipy` for scientific modeling
# * `StatisticsModels` for statistical modeling

# %% [markdown]
# ###🔖 **Libraries used in PCC MATH 065 Mathematical and Scientific Programming**
# * `NumPy` for numerical computation, matrices, and random numbers
# * `SymPy` for symbolic algebrain Math
# * `matplotlib`, `seaborne`, and `plotly` for visualization
# * `Scipy` for scientific modeling
# * `StatisticsModels` for statistical modeling
# * `OpenCV Python` for Computer ision
# * `Tensor Flow` end to end machine learning platform on Colab
# * `Beautiful soup` for web scraping
# * `Requests` and API send HTTP/1.1 requests retrieve the answer data.
# * `Scikid-learn` for data analysis library and the gold standard for Machine Learning (ML) in the Python ecosystem.
