# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #$$\textbf{🏷 Simple Random Sampling 🏷}$$

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work: }}$Simple Random Sampling from a Population as a list of names**
#
#  In statitics, we will use the concept of population and create sample from the population randomly.  The population is often in the format of an data structure or array.  Sampling can be with replacement and not replacement.
#
# <details>
#   <summary><b>Show definition of Sampling with Replacement or Without Replacement </b></summary>
#
# Sampling may be done <b> with replacement</b> or <b> without replacement </b>.
#
# * <b>With replacement:</b>  If each member of a population is replaced <b>after it is picked,</b> then that member has the possibility of being chosen moe than once.  When sampling is done with replacement, then events ae considered to be independent, meaning the result of the first pick will not change the probabilities for the second pick.
#
# * <b> Without replacement:</b> When sampling is done without replaement, each member of a population may be chosen only once.  In this case, the probabilities for the second pick are affected by the result of the first pick.  The events are considered to be dependent or not independent.
#
# </details>

# %% [markdown]
# #### **1. Define the population from a roster of class**
#
# "Anselmo", "Bautista", "Bayani", "cheng", "Cuarismo", "Cuningham", "Fontecha", "Hong", "Hoobler","Jiao", "Khan", "King", "Legeny", "Lundquist", "Macierz", "Motogawa", "Okimoto", "patel", "Price", "Quizon", "Reyes", "Roquero", "Roth", " Rowell", "Salangsang", "Slade", "Stratcher", "Tallar", "Tran","Wai", "Wood"

# %%
import numpy as np

population = [
    "Anselmo", "Bautista", "Bayani", "cheng", "Cuarismo", "Cuningham", "Fontecha", "Hong", "Hoobler","Jiao",
    "Khan", "King", "Legeny", "Lundquist", "Macierz", "Motogawa", "Okimoto", "patel", "Price", "Quizon", "Reyes",
    "Roquero", "Roth", " Rowell", "Salangsang", "Slade", "Stratcher", "Tallar", "Tran","Wai", "Wood"
]

# %% [markdown]
# #### **2. Sampling to create a sample with size = 1 (one name)**

# %%
sample_one = np.random.choice(population)
print(f"Population sample size of one: {sample_one}")
# Out:
# Population sample size of one: Hong

# %% [markdown]
# #### **3. Sampling by randomly choosing more than one with equal probability with replacement**

# %%
multiple_samples_replacement = np.random.choice(population, size=4, replace=True)
print(f"Multiple samples with replacement: {multiple_samples_replacement}")
# Out:
# Multiple samples with replacement: ['Cuarismo' 'Hong' 'Wood' 'Macierz']

# %% [markdown]
# #### **4. Sampling by randomly choosing more than one with equal probability without replacement**

# %%
multiple_samples_no_replacement = np.random.choice(population, size=5, replace=False)
print(f"Multiple samples without replacement: {multiple_samples_no_replacement}")
# Out:
# Multiple samples without replacement: ['Stratcher' 'Roquero' 'Jiao' 'Slade' 'Price']

# %% [markdown]
# ### **$\color{orange}{\textbf{Tip:}}$ $\color{magenta}{\text{What you learned above coding?}}$**.
#
# * To create a **string** in Python, you need to place the content between two double-quotes **" "** or single quotes**' '**.
# * To create a **list** in Python you need to put the data between **[** and **]** with comma to separate data points.

# %% [markdown]
# ---
# ### 🧚 **$\color{green}{\textbf{TO DO:}}$ Follow the example above to do the following**

# %% [markdown]
# #### **1. Create a modified population from the class roster above**
# * Add a code cell below
# * Copy and past the list above to the code cell.
# * Add three new names of your choices to the population.
#
# $\color{red}{\text{Make sure that you use the correct syntax following the example}}$

# %%
population = [
    "Anselmo", "Bautista", "Bayani", "cheng", "Cuarismo", "Cuningham", "Fontecha", "Hong", "Hoobler","Jiao",
    "Khan", "King", "Legeny", "Lundquist", "Macierz", "Motogawa", "Okimoto", "patel", "Price", "Quizon", "Reyes",
    "Roquero", "Roth", " Rowell", "Salangsang", "Slade", "Stratcher", "Tallar", "Tran","Wai", "Wood",
    # Add new names
    "Miles", "Mae", "Misty", "Tim", "Danielle"
]

# %% [markdown]
# ####**2. Create one sample with 7 names ramdomly selected from the population without replacement.**
# **Run your code to see the output**

# %%
random_names_no_replacement = np.random.choice(population, 7, replace=False)
print(f"Sample with seven names selected without replacement: {random_names_no_replacement}")
# Out:
# Sample with seven names selected without replacement: ['Roth' 'Hoobler' 'Okimoto' 'Price' 'Jiao' 'Anselmo' 'Motogawa']

# %% [markdown]
# ####**3. Create one sample with 4 names ramdomly selected from the population with replacement.**
# $\color{red}{\text{Run your code repeatedly until the outcome shows at least one duplicated name in your sample.}}$

# %%
random_names_replacement = np.random.choice(population, 4, replace=True)
print(f"Sample with four names selected with replacement: {random_names_replacement}")
# Out:
# Sample with four names selected with replacement: ['cheng' 'cheng' 'Fontecha' 'Lundquist']

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work: }}$Simple Random Sampling from a Population as a list of random numbers**

# %% [markdown]
# ## **Syntax for generating random numbers**
# ### **Code Structure:** $\hspace{20mm}$ ```numpy.random.```$\color{blue}{\text{source}}( \color{magenta}{\text{parameters}})$

# %% [markdown]
# |functionality| $\color{blue}{\textbf{Souces syntax }}$($\color{magenta}{\textbf{parameters }}$)| outputs|
# |--|--|--|
# |A Range of Numbers | ```randint(low, high, size, dtype)``` |Return random integers from low (inclusive) to high(exclusive), <br> or if endpoint=True, low (inclusive) to high (inclusive)|
# |  | ```random(size)```|Return random floats in the half-open interval [0.0, 1.0)|
# | | ```randn(d0, d1, ...)```|Return a given shape filled with random floats from a standard normal distribution|
# | | ```rand(d0, d1, ...)```|Return a given shape filled with

# %% [markdown]
# ---
# ### **1. Create a population of with random $\color{red}{\text{integers}}$ between  ```low = 0``` and `high`, with ```size```**

# %%
size = 100
high = 100000
random_integers = np.random.randint(low=0, high=high, size=size)
print(f"The population of random integers is: {random_integers}")
# Out:
# The population of random integers is: [60051 65507 24671  4915 53677 50665 19480 21229 42001 91099  9789  9965
#  12637 45570 70829 28828 88853 11950 58769   678 50281 63286 18741 52351
#  10689 30569 62887  9078   107 86036 58625 60435 81524 15844 36328  5850
#  91641 47675 79267 33089 57283 21110  8073 56288 15552 13779 67257 14290
#  57052 19567 69516 51340 79006 97609 35988 40787 74511 55486  8846 47240
#  54016 64974 46604 10504  6742 23104 95276 61665 20253  8897 69011 18663
#   4297  3205 11298  1180 76129 56136 63116 54003 25735 30064 85959  8221
#    906 45991 96244  7514 79315 68541 45039 21405  2662 44996 31042 58201
#  41038 78656 58550 68126]

# %% [markdown]
# ####**2. Create one sample of size = `sample_size` with simple ramdom selection from the population1 without replacement.**

# %%
sample_size = 5
random_sample_no_replacement = np.random.choice(random_integers, size=sample_size, replace=False)
print(f"The simple random selection without replacement is: {random_sample_no_replacement}")
# Out:
# The simple random selection without replacement is: [19567 45991 67257 58201 42001]

# %% [markdown]
# ####**3. Create one sample of size = `sample_size` with simple ramdom selection from the population1 with replacement.**

# %%
sample_size = 5
random_sample_replacement = np.random.choice(random_integers, size=sample_size, replace=True)
print(f"The simple random selection with replacement is: {random_sample_replacement}")
# Out:
# The simple random selection with replacement is: [60435 45039  6742 52351   906]

# %% [markdown]
# ## 🧚 **$\color{green}{\textbf{TO DO:}}$ Follow the example above to do the following**

# %% [markdown]
# #### **1.** Define a variable ```population_int``` with a population of 100,000 integers between 0 and 5000.

# %%
population_int = np.random.randint(low=0, high=5000, size=100000)
print(f"The size of the variable `population_int` is: {len(population_int)}")
# Out:
# The size of the variable `population_int` is: 100000

# %% [markdown]
# #### **2.** Creating a Sample Using simple random sampling with replacement
# * Define a variable ```sample1``` of size 3000 integers via simple random sampling from the population_int **with** replacement.
# * Use `f-string` to print out the `sample1` with description as that in the example above

# %%
sample1 = np.random.choice(population_int, size=3000, replace=True)
print(f"The results of the random sample with replacement are: {sample1}")
# Out:
# The results of the random sample with replacement are: [1839 2686 1504 ... 2737 2734 2773]

# %% [markdown]
# #### **3.** Creating a Sample Using simple random sampling without replacement
# * Define a variable ```sample2``` of size 500 integers via simple random sampling from the population_int with ** without** replacement,
# * Use `f-string` to print out the `sample2` with description as that in the example above

# %%
sample2 = np.random.choice(population_int, size=500, replace=False)
print(f"The results of the random sample without replacement are: {sample2}")
# Out:
# The results of the random sample without replacement are: [4412 3597 1022 4863  612 3369 1201 3759  245 1776 2606  928  855 4123
#  4258  122 2792 2660  988 2162 2528  880 2041 2163 3418 3052  976 1851
#  1603 3199 2134 4249 2167 2555 4262   60  429 3436 4944 1858 3163 3701
#  4026  435 1485 1282 1588 2745  868 4330  338 4446 3664 1829 4737 3779
#   378 3997  781 4564 1824 1773 2270 4018  989 1904  433 3665 3928  174
#  4886 1290 4403 4665 2364 1697 3729 4833  607  324 2876 3529 3069 1976
#  2987 1314  371 4750 1924 1088 3156 3210 4455  169 1059 1827 3104 3118
#  4292 4264 3006  159 4343 1269 4879 1852 1310 3055 1987 4132 1785  835
#   343 2868 1669 4020 4005 1319  492 4053 2377 4443 3769 4992   40 4250
#  3357   24 4160 2132  621 1073  949 2290 3787 4687 2295 2103 2930 1796
#   684 1709  841  610 2325 2390 2524 3968 3209 1207 2242   31 3659 1233
#  4053 1097 2885 4324   98 2924 1957 2097 1381 3765 1346  946 4929 1605
# ...
