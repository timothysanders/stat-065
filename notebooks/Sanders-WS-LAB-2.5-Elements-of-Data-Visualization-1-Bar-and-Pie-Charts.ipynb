# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # $$\hspace{80mm} \textbf{Data Visualizations}$$
#
# <details>
#   <summary><font size = 4.5px><b>Show Definition</b></font></summary>
#
# In the field of <b>statistics </b>, data is vital. Data is the information that you collect to learn, draw conclusions, and test hypotheses.  After all, statistics is the science of learning from data.
#
# There are different types of variables, and these variables represent various kinds of information.  Crucially, the type of information determines what you **can** learn from it, and, more importantly, what you $\color{red}{\text{cannot}}$ learn from it.  Consequently, it's essential that you understand the different types of data.
# </details>
#
#
# <details>
#   <summary><font size = 4.5px><b>Show Review of Data Types</b></font></summary>
#
# **Qualitative Data** is the result of categorizing or describing attributes of a population.  Qualitative data is often called **categorical data** when the data takes the form of belonging to a category (like freshman, sophomore, junior, or senior).
#
# **Quantitative Data** are always numbers.  Quantitative data are the result of **counting** or **measuring** attributes of a population.  **Quantitative discrete data** is data that can be counted on your fingers (if you had enough fingers).  The number of people who eat breakfast would be an example of discrete data.
#
# **Quantitative continuous data** are both made up of counting numbers and may also include fractions, decimals, or irrational numbers.  Continuous data is $\color{red}{\text{not}}$ countable.  Distance and length are examples of continuous data.
#   </details>
#
# <details>
#   <summary><b><font size = 4.5px>Why Data Visualizations is Critical?</b></font></summary>
#
#
#
# [Why do we need to visualize data sets?](https://www.research.autodesk.com/publications/same-stats-different-graphs/)
#
# There are data sets which are identical over a number of statistical properties but produce dissimilar graphs. Use the link above to see various data sets which illustrate the importance of always using graphical representations when exploring data.
#
# [Animation without descriptive statistics](https://damassets.autodesk.net/content/dam/autodesk/research/publications-assets/gifs/same-stats-different-graphs/same-stats-different-graphs-image-1920x1000.gif)
#
# [Animation with the descriptive statistics](https://damassets.autodesk.net/content/dam/autodesk/research/publications-assets/gifs/same-stats-different-graphs/CloudToCircle.gif)
#
# [Summary of all phases with descriptive statistics](https://damassets.autodesk.net/content/dam/autodesk/research/publications-assets/images/AllDinosGrey_1.png)
#
# </details>
#
# <details>
#   <summary><font size = 4.5px><b>Elements of Data Visualization in this course</b></font></summary>
#
# * LAB 2.5 Elements of Data Visualization 1 - Bar Chart
# * LAB 3.1 Elements of Data Visualization 2 -  Histogram
# * LAB 3.2 Elements of Data Visualization 3 - Scatter Plots
# * LAB 3.3 Elements of Visualization 4 - Time Series
# * LAB 3.4 Elements of Visualization 5 - Boxplots
# * LAB 6.1 Elements of Data Visualization 6 - Heatmaps
# </details>

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # **Element of Data Visualization - <font color = "violet"> Bar Graph or Bar Chart</font>**
# <details>
#   <summary><b>Show description</b></summary>
#
# <b>Bar graphs</b> are a standard way to visualize data from qualitative (categorical) data as well as discrete quantitative variables.
#
#  <b>Bar chart</b> (same as bar graph) is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally.
# </details>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work 1:}}$ Create a Bar Graph**
#
# <details>
#   <summary><b>Show the problem</b></summary>
# By the end of 2011, Facebook had over 146 million users in the United States. The table shows three age groups, the number of Facebook users in each age group, and the proportion (%) of users in each age group.
#
# Construct a bar graph using this data.
#
#
# |Age groups 	|Number of Facebook users |	Proportion (%) of Facebook users|
# |--|--|--|
# |13−25|	65,082,280|	45%|
# |26−44|	53,300,200|	36%|
# |45−64|	27,885,100|	19%|
#
# </details>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### **A.  Create data structures**

# %%
data = {
    "Age groups": ["13-25", "26-44", "45-64"],
    "Number of Facebook users": [65082280, 53300200, 27885100],
    "Proportion (%) of Facebook users": [45, 36, 19]
}
data
# Out:
# {'Age groups': ['13-25', '26-44', '45-64'],
#  'Number of Facebook users': [65082280, 53300200, 27885100],
#  'Proportion (%) of Facebook users': [45, 36, 19]}

# %%
df_fb = pd.DataFrame(data)
df_fb
# Out:
#   Age groups  Number of Facebook users  Proportion (%) of Facebook users
# 0      13-25                  65082280                                45
# 1      26-44                  53300200                                36
# 2      45-64                  27885100                                19

# %% [markdown]
# ####**B.  Create Static Bar chart using matplotlib**

# %%
# Matplotlib tutorial: https://matplotlib.org/stable/tutorials/pyplot.html#pyplot-tutorial
fig = plt.figure(figsize=(7, 5))

plt.bar(
    df_fb["Age groups"],
    df_fb["Proportion (%) of Facebook users"],
    color="green",
    width=0.4,

)

plt.xlabel('Age group')
plt.ylabel('Proportion of users')
plt.title("Facebook User Distributions (2011)")
plt.show()

# %% [markdown]
# ####**C.  Create Interactive Bar chart using plotly**

# %%
# Plotly tutorial: https://plotly.com/python/getting-started/
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(
    go.Bar(
        # Categorical value goes on the x-axis
        x=df_fb["Age groups"],
        y=df_fb["Proportion (%) of Facebook users"],
        text=df_fb["Proportion (%) of Facebook users"],
        textposition="auto",
        marker=dict(
            # color picker: https://duckduckgo.com/?t=ffab&q=color+picker&ia=answer
            color="RGBA(80,180,80,0.5)", # the last number is the transparency
            line=dict(
                color="#12190c",
                width=1
            )
        )
    )
)
# Add layout
fig.update_layout(
    width=500,
    height=400,
    xaxis_title="Age group",
    yaxis_title="Proportion (%) of users",
    title="Facebook User Distribution (2011)",
    title_x=0.5,
    font_size=12
)

fig.show()
# If swapping x/y axes, then the bar chart will show as a horizontal bar chart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **Discussion:**
# > **1.** Does the width of each bar represent some meaning of the data?
#
# >**2.** What do you think that we use various widths in the bar chart.

# %% [markdown]
# 1. For a bar chart, the width would not necessarily represent anything with the data. A histogram, on the other hand, does represent meaning for the data in the width of the bars.
# 2. We might use various widths in a bar chart (not a histogram) to help create a more visually appealing chart. For example, if we are creating more verbose labels on the tops of our bars, then it might make sense to have the bars themselves be wider, so that the label of the bar fits within the bar.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##**$\color{green}{\textbf{TO DO 1:}}$** Create a static bar graph using AP examinee population and an interactive bar chart using the overall student population.
#
# <details>
#   <summary><b>Show the problem</b></summary>
# The columns in table below contain the race or ethnicity of students in U.S. public schools for the class of 2011, percentages for the Advanced Placement examinee population for that class, and percentages for the overall student population.
#
# |Race/Ethnicity 	|AP Examinee Population |	Overall Student Population|
# |--|--|--|
# |1 = Asian, Asian American or Pacific Islander| 10.3%|5.7% |
# |2 = Black or African American	 ‌|9.0%	‌|14.7%|
# |3 = Hispanic or Latino ‌|17.0%	|‌17.6%|
# |4 = American Indian or Alaska Native ‌|0.6%	|‌1.1%|
# |5 = White|57.1% | 59.2%|
# |6 = Not reported/other|6.0%  |1.7% |
#
# </details>

# %% [markdown]
# #### **A. Create a data frame from the data**

# %% [markdown]
# ####**B. Create a static bar chart** with the following attributes of layout
# * x and y axis labels
# > Use **`plt.xticks(rotation=-30, ha='left')`** to create a slant x-axis labels.\
# > Use **`plt.xticks(rotation=30, ha='right')`** to create a slant x-axis labels.
# * A plot title

# %%
ap_examinee_data = {
    "Race/Ethnicity": [
        "1 - Asian, Asian American or Pacific Islander",
        "2 = Black or African American",
        "3 = Hispanic or Latino ",
        "4 = American Indian or Alaska Native",
        "5 = White",
        "6 = Not reported/other"
    ],
    "AP Examinee Population": [
        10.3,
        9.0,
        17.0,
        0.6,
        57.1,
        6.0
    ]
}
ap_examinee_df = pd.DataFrame(ap_examinee_data)

# %%
fig = plt.figure(figsize=(7, 5))

plt.bar(
    ap_examinee_df["Race/Ethnicity"],
    ap_examinee_df["AP Examinee Population"],
    color="green",
    width=0.4,

)

plt.xlabel("Race/Ethnicity")
plt.ylabel("AP Examinee Population (%)")
plt.title("AP Examinee Population by Race/Ethnicity (2011)")
plt.xticks(rotation=-45, ha='left')
plt.show()

# %% [markdown]
# ####**C.  Create an interactive bar chart** with the same attributes of layout as the static Bar chart in **B.**

# %%
overall_data = {
    "Race/Ethnicity": [
        "1 - Asian, Asian American or Pacific Islander",
        "2 = Black or African American",
        "3 = Hispanic or Latino ",
        "4 = American Indian or Alaska Native",
        "5 = White",
        "6 = Not reported/other"
    ],
    "Overall Population": [
        5.7,
        14.7,
        17.6,
        1.1,
        59.2,
        1.7
    ]
}
overall_df = pd.DataFrame(overall_data)

# %%
fig = go.Figure()
fig.add_trace(
    go.Bar(
        x=overall_df["Race/Ethnicity"],
        y=overall_df["Overall Population"],
        text=overall_df["Overall Population"],
        textposition="auto",
        marker=dict(
            color="RGBA(80,180,80,0.5)",
            line=dict(
                color="#12190c",
                width=1
            )
        )
    )
)

fig.update_layout(
    width=750,
    height=600,
    xaxis_title="Race/Ethnicity",
    yaxis_title="Overall Population",
    title="Overall Population by Race/Ethnicity (2011)",
    title_x=0.5,
    font_size=12
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **D. Discussion:**
# > **1.** Does the width of each bar represent some meaning of the data?
#
# > **2.** What do you think is the reason we use various widths in the bar chart?

# %% [markdown]
# 1. In our examples here, we do not have any particular meaning associated with the width of the bars in the bar chart themselves, only in the heights of the bars.
# 2. In our bar chart, we could use different widths to help arrange our labels in a more pleasing way, for example, if we chose wider bars, we might not have to slant our x-axis labels in the same way, though at the cost of filling up the page with a much larger diagram that does not have additional meaning.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work 2:}}$ Create a grouped bar graph using list data structure**
#
# <details>
#   <summary><b>Show the problem</b></summary>
# Park city is broken down into six voting districts. The table shows the percent of the total registered voter population that lives in each district as well as the percent total of the entire population that lives in each district.
#
# a. Write Python code to construct a bar graph that shows the registrations by the district.
#
# |District 	|Registered voter population |	Overall city population|
# |--|--|--|
# |Distict 1| 16.5%|18.4% |
# |Distict 2 ‌|9.2%	‌|14.6%|
# |Distict 3 ‌|11.8%	|‌9.1%|
# |Distict 4‌|16.4%	|‌18.5%|
# |Distict 5|25.8% | 20.7%|
# |Distict 6 |20.3%  |18.7% |
#
#
# </details>

# %%
# Do not always have to create a dataframe to create a graph
# For this problem, we need to create three Series objects
district = [
    "Distict 1",
    "District 2",
    "District 3",
    "District 4",
    "District 5",
    "District 6"
]
voter_population = [
    16.5,
    9.2,
    11.8,
    16.4,
    25.8,
    20.3
]
city_population = [
    18.4,
    14.6,
    9.1,
    18.5,
    20.7,
    18.7
]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.Figure(figsize=(10, 5))
# assign axis label
x_axis = np.arange(len(district))
# shift x axis
plt.bar(
    x_axis - 0.2, voter_population, color="green", width=0.4, label="Voter Population (%)"
)
plt.bar(
    x_axis + 0.2, city_population, color="blue", width=0.4, label="City Population (%)"
)
# add layout
plt.xticks(x_axis, district)
plt.xlabel("Districts")
plt.ylabel("Population (%)")
plt.title("Voter Registration by District")
plt.legend()
plt.show()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##**$\color{green}{\textbf{TO DO 2:}}$** Create a grouped bar chart with the following data.
#
# <details>
#   <summary><b>Show the problem</b></summary>
# The columns in table below contain the race or ethnicity of students in U.S. public schools for the class of 2011, percentages for the Advanced Placement examinee population for that class, and percentages for the overall student population.
#
# |Race/Ethnicity 	|AP Examinee Population |	Overall Student Population|
# |--|--|--|
# |1 = Asian, Asian American or Pacific Islander| 10.3%|5.7% |
# |2 = Black or African American	 ‌|9.0%	‌|14.7%|
# |3 = Hispanic or Latino ‌|17.0%	|‌17.6%|
# |4 = American Indian or Alaska Native ‌|0.6%	|‌1.1%|
# |5 = White|57.1% | 59.2%|
# |6 = Not reported/other|6.0%  |1.7% |
#
# </details>

# %%
race_ethnicity = [
    "1 = Asian, Asian American or Pacific Islander",
    "2 = Black or African American",
    "3 = Hispanic or Latino",
    "4 = American Indian or Alaska Native",
    "5 = White",
    "6 = Not reported/other"
]
ap_examinee_population = [
    10.3,
    9.0,
    17.0,
    0.6,
    57.1,
    6.0
]
overall_population = [
    5.7,
    14.7,
    17.6,
    1.1,
    59.2,
    1.7
]

# %% [markdown]
# ####**A. Create a static bar chart.**
# **Required components:**
# * Two lists Data structures
# * A grouped static bar graphs with the follow attributes:
# > * x and y axis labels
# >> Use **`plt.xticks(rotation=-30, ha='left')`** to create a slant x-axis labels.\
# >> Use **`plt.xticks(rotation=30, ha='right')`** to create a slant x-axis labels.
# >* Legend of each group
# >* A plot title
# * A short summary of verification if your plot is true to the data.

# %%
plt.Figure(figsize=(10, 5))
# assign axis label
x_axis = np.arange(len(race_ethnicity))
# shift x axis
plt.bar(
    x_axis - 0.2, ap_examinee_population, color="green", width=0.4, label="AP Examinee Population (%)"
)
plt.bar(
    x_axis + 0.2, overall_population, color="blue", width=0.4, label="Overall Student Population (%)"
)
# add layout
plt.xticks(x_axis, race_ethnicity, rotation=30, ha='right')
plt.xlabel("Race/Ethnicity")
plt.ylabel("Students (%)")
plt.title("Student Proportions by Race/Ethnicity")
plt.legend()
plt.show()

# %% [markdown]
# To verify that our plot is true to our original data, we can spot check some of the values that we have in our original data (replicated below) against what is shown in the graph.
# ```python
# ap_examinee_population = [
#     10.3,
#     9.0,
#     17.0,
#     0.6,
#     57.1,
#     6.0
# ]
# overall_population = [
#     5.7,
#     14.7,
#     17.6,
#     1.1,
#     59.2,
#     1.7
# ]
# ```
# For example, we have "Asian, Asian American or Pacific Islander" with an AP examinee population of `10.3`. Looking at the graph, we see that this green bar lines up very closely with `10` on the y-axis. Additionally, we should see the blue, overall population bar for this group at roughly half the height, which indeed, it is. Also, we see that the two bars for "White" are both the tallest bars by far, with the overall population bar being slightly taller than the AP examinee bar.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work 3:}}$ Create Pie Chart**

# %% [markdown]
# #### **Create a data frame**

# %%
data = {
    "Age groups": ["13-25", "26-44", "45-64"],
    "Number of Facebook users": [65082280, 53300200, 27885100],
    "Proportion (%) of Facebook users": [45, 36, 19]
}
df_fb = pd.DataFrame(data)

# %% [markdown]
# ####**Pie Chart Using matplotlib**

# %%
plt.Figure(figsize=(10, 10))
plt.pie(
    df_fb["Number of Facebook users"],
    explode=[0.05, 0.05, 0.05], # creates a gap between the first and second piece
    labels=df_fb["Age groups"],
    colors=["#0c190c", "#1a38a5", "#6ba51a"]
)
plt.title("Age Distribution of Facebook Users (2011)")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Facebook Users (2011)')

# %% [markdown]
# #### **Interactive Pie Chart Using plotly**

# %%
fig = go.Figure()
fig.add_trace(
    go.Pie(
        values=df_fb["Number of Facebook users"],
        labels=df_fb["Age groups"],
        pull=[0, 0, 0.06],
        textinfo="label+percent"
    )
)
fig.update_layout(
    width=600,
    height=600,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##**$\color{green}{\textbf{TO DO 3:}}$**
# #### Use the data from the California Air Resource Board: [California Greenhouse Total Gas Emissions from 2000 to 2021](https://ww2.arb.ca.gov/ghg-inventory-data):

# %% [markdown]
# **Emission Trends and Indicators**
#
# | Sector|2021 Emissions (MMTCO$_{2e}$)|Percentage|
# |:--|--:|--:|
# |Transporttion|145.6|38.2%|
# |Industrial|73.9|19.4%|
# |Electricity|62.4|16.4%|
# |Residential & Commercial|38.8|10.2%|
# |Agriculture|30.9|8.1%|
# |High GWP| 21.3|5.6%
# |Waste|8.4|2.2%|

# %% [markdown]
# #### **A.** Create a Data Frame from the table in the problem.

# %%
emissions_data = {
    "Sector": [
        "Transportation",
        "Industrial",
        "Electricity",
        "Residential & Commercial",
        "Agricultural",
        "High GWP",
        "Waste"
    ],
    "2021 Emissions (MMTCO2e)": [
        145.6,
        73.9,
        62.4,
        38.8,
        30.9,
        21.3,
        8.4
    ],
    "Percentage": [
        38.2,
        19.4,
        16.4,
        10.2,
        8.1,
        5.6,
        2.2
    ]
}
emissions_df = pd.DataFrame(emissions_data)

# %% [markdown]
# #### **B.** Create an interactive bar chart of section vs. 2021 Emission.  Make sure that you label the axes, titles, and each bar with the data.
# > Use **`plt.xticks(rotation=-30, ha='left')`** to create a slant x-axis labels.\
# > Use **`plt.xticks(rotation=30, ha='right')`** to create a slant x-axis labels.

# %%
fig = go.Figure()
fig.add_trace(
    go.Bar(
        x=emissions_df["Sector"],
        y=emissions_df["2021 Emissions (MMTCO2e)"],
        text=emissions_df["2021 Emissions (MMTCO2e)"],
        textposition="auto",
        marker=dict(
            color="RGBA(80,180,80,0.5)",
            line=dict(
                color="#12190c",
                width=1
            )
        )
    )
)

fig.update_layout(
    width=750,
    height=600,
    xaxis_title="Sector",
    yaxis_title="2021 Emissions (MMTCO2e)",
    title="2021 Emissions (MMTCO2e) by Sector",
    title_x=0.5,
    font_size=12
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **C.** Create an interactive bar chart of section vs. 2021 Emissions as a percentage.  Label the pieces and titles appropriately.

# %%
fig = go.Figure()
fig.add_trace(
    go.Bar(
        x=emissions_df["Sector"],
        y=emissions_df["Percentage"],
        text=emissions_df["Percentage"],
        textposition="auto",
        marker=dict(
            color="RGBA(80,180,80,0.5)",
            line=dict(
                color="#12190c",
                width=1
            )
        )
    )
)

fig.update_layout(
    width=750,
    height=600,
    xaxis_title="Sector",
    yaxis_title="Percentage 2021 Emissions (MMTCO2e)",
    title="Percentage of 2021 Emissions (MMTCO2e) by Sector",
    title_x=0.5,
    font_size=12
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **D.** Write a short summary of verification if the bar graph agrees with your is true to the data.
#
# #### **E.** Write a short discussion of the trend from your analysis.

# %% [markdown]
# ##### D
# To validate our chart, we can look at the data that is shown in both of the bar graphs to ensure that it matches what is in the data frame that we constructed and passed to the code to build the graphs. Plotly helpfully adds labels on top of the bars in each graph, so we are able to see very easily that the data in the graph does indeed match what is in our data frame. An additional check would be to verify that we created our data frame correctly in the first place from the original problem set data, there are no typos, etc.
# ##### E
# While we can see a downward trend when moving from left to right in our graphs, what would make this analysis more interesting would be to compare how much a particular sector contributes to the overall country GDP, or the number of jobs, etc. Using GDP, the [Bureau of Transportation Statistics](https://www.bts.gov/newsroom/transportation-services-contributed-56-us-gdp-2021-increase-54-2020-below-58-2019) reported that transportation services accounted for 5.6% of GDP in 2021, while accounting for 38.2% of the MMTCO2e in our chart. So by comparison to other sectors, the transportation sector accounts for a much larger emissions level than its GDP contribution.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##**$\color{green}{\textbf{TO DO 4: Option}}$**
# <details>
#   <summary><b>Show the problem</b></summary>
# The population in Park City is made up of children, working-age adults, and retirees. The table below shows the three age groups, the number of people in the town from each age group, and the proportion (%) of people in each age group.
#
# |Age groups |	Number of people |	Proportion of population|
# |--|--|--|
# |Children |	67,190|	19%|
# |Working-age adults |	159,593|	46%|
# |Retirees |	121,808|	35%|
#
#
# </details>

# %% [markdown]
# #### **A. Create the pandas dataframe.**

# %%
park_population = {
    "Age groups": ["Children", "Working-age adults", "Retirees"],
    "Number of people": [67190, 159593, 121808],
    "Proportion of population": [19, 46, 35]
}
park_df = pd.DataFrame(park_population)

# %% [markdown]
# #####**B. Create an bar graph of `Age group` vs `Number of people` in each group** and show x and y axis labels, and a title
# > Use **`plt.xticks(rotation=-30, ha='left')`** to create a slant x-axis labels.\
# > Use **`plt.xticks(rotation=30, ha='right')`** to create a slant x-axis labels.

# %%
fig = plt.figure(figsize=(7, 5))

plt.bar(
    park_df["Age groups"],
    park_df["Number of people"],
    color="blue",
    width=0.4
)

plt.xlabel("Age groups")
plt.ylabel("Number of people")
plt.title("Number of people in Park City by age group")
plt.xticks(rotation=30, ha='right')
plt.show()

# %% [markdown]
# ##### **C. Create an interactive Pie chart of "Prop (%) of population` in each `Age group`**

# %%
fig = go.Figure()
fig.add_trace(
    go.Pie(
        values=park_df["Proportion of population"],
        labels=park_df["Age groups"],
        pull=[0, 0, 0.05],
        textinfo="label+percent"
    )
)
fig.update_layout(
    width=600,
    height=600,
    title="Proportion of population in Park City by age group",
    title_x=0.5,
    font_size=12
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **D.** What can you say about your graphic analysis?

# %% [markdown]
# According to data retrieved from [census.gov](https://docs.google.com/spreadsheets/d/1SkYHXAKH4mVpmAhs9K-gk2oG4JOdiQSi/edit?usp=sharing&ouid=108337475038456775955&rtpof=true&sd=true), 22.45% of the US population (as of 2023) was under 18 years of age and 16.34% of the population was 65 years of age or older. What this means is that the demographics of Park City skew significantly older than the US population as a whole (assuming that "Retirees" means 65+ years of age).
