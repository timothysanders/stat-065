# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #$$\textbf{🏷 Probability Sampling: Ramdom Sampling from a Probability Distribution 🏷}$$

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work:}}$ Probability Sampling from a population with probabilities as a list**

# %% [markdown]
# #### **1. Define the population as a list of names** with probability p=[0.1, 0, 0.3, 0.4, 0, 0.2], the name with the highest probability 0.4 has more chance than others to be selected in a sample.
# #### **Note:** The probability must sum to 1

# %%
candidates = ["Miles", "Misty", "Mae", "Danielle", "Tim", "Betsy"]
p = [0.1, 0, 0.3, 0.4, 0, 0.2]

# %% [markdown]
# #### **2.** Create a sample of size 4 `without replacement` by probability sampling using the given probability distribution

# %%
import numpy as np

sample = np.random.choice(
    candidates,
    replace=False,
    p=p
)
print(f"The sample from the population {candidates}\nwithout replacement with a probability distribution {p} is:\n{sample}")
# Out:
# The sample from the population ['Miles', 'Misty', 'Mae', 'Danielle', 'Tim', 'Betsy']
# without replacement with a probability distribution [0.1, 0, 0.3, 0.4, 0, 0.2] is:
# Danielle

# %%
sample = np.random.choice(
    candidates,
    size=4,
    replace=False,
    p=p
)
print(f"The sample (of size 4) from the population {candidates}\nwithout replacement with a probability distribution {p} is:\n{sample}")
# Out:
# The sample (of size 4) from the population ['Miles', 'Misty', 'Mae', 'Danielle', 'Tim', 'Betsy']
# without replacement with a probability distribution [0.1, 0, 0.3, 0.4, 0, 0.2] is:
# ['Miles' 'Danielle' 'Mae' 'Betsy']

# %% [markdown]
# #### **3.** Create a sample of size 4 `with replacement` by probability sampling using the given probability distribution

# %%
sample = np.random.choice(
    candidates,
    size=4,
    replace=True,
    p=p
)
print(f"The sample (of size 4) from the population {candidates}\nwithout replacement with a probability distribution {p} is:\n{sample}")
# Out:
# The sample (of size 4) from the population ['Miles', 'Misty', 'Mae', 'Danielle', 'Tim', 'Betsy']
# without replacement with a probability distribution [0.1, 0, 0.3, 0.4, 0, 0.2] is:
# ['Betsy' 'Danielle' 'Betsy' 'Danielle']

# %% [markdown]
# ## 🧚 **$\color{green}{\textbf{TO DO:}}$ Follow the example above to do the following**

# %% [markdown]
# #### **1. Define the population**
# * open a code cell below
# * Create a population with 7 names (You can copy/paste from the LabWork and then add another name)
# * Copy the probability distribution `p` and then add the probability 0.1 to `p` for the 7th name. (adjust other probability values in `p` so that the sum of the probability in `p` is 1.
# #### **Note:** The probability must sum to 1

# %% [markdown]
# `p=[0.1, 0, 0.3, 0.3, 0, 0.2, 0.1]`

# %%
candidates = ["Miles", "Misty", "Mae", "Danielle", "Tim", "Betsy", "Skittles"]
p=[0.1, 0.1, 0.2, 0.2, 0.1, 0.2, 0.1]

# %% [markdown]
# #### **2.** Create a sample of size 3 `without replacement` by probability sampling using the given probability distribution
# #### **print out the sample with description**

# %%
sample_size = 3
sample = np.random.choice(
    candidates,
    size=sample_size,
    replace=False,
    p=p
)
print(f"The sample (of size {sample_size}) from the population {candidates}\nwithout replacement with a probability distribution {p} is:\n{sample}")
# Out:
# The sample (of size 3) from the population ['Miles', 'Misty', 'Mae', 'Danielle', 'Tim', 'Betsy', 'Skittles']
# without replacement with a probability distribution [0.1, 0.1, 0.2, 0.2, 0.1, 0.2, 0.1] is:
# ['Mae' 'Danielle' 'Misty']

# %% [markdown]
# #### **3.** Create a sample of size 5 `with replacement` by probability sampling using the given probability distribution.
# #### **print out the sample with description**

# %%
sample_size = 5
sample = np.random.choice(
    candidates,
    size=sample_size,
    replace=True,
    p=p
)
print(f"The sample (of size {sample_size}) from the population {candidates}\nwithout replacement with a probability distribution {p} is:\n{sample}")
# Out:
# The sample (of size 5) from the population ['Miles', 'Misty', 'Mae', 'Danielle', 'Tim', 'Betsy', 'Skittles']
# without replacement with a probability distribution [0.1, 0.1, 0.2, 0.2, 0.1, 0.2, 0.1] is:
# ['Misty' 'Tim' 'Betsy' 'Mae' 'Skittles']

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Create Samples by sampling with standard probability distributions: Uniform, Binomial, Normal**

# %% [markdown]
# ### **Syntax Structure:** $\hspace{20mm}$ ```numpy.random.```$\color{blue}{\text{distribution}}( \color{magenta}{\text{parameters}})$
#
# <details>
#   <summary><b>Show Syntax:$\color{blue}{\text{ distribution}}( \color{magenta}{\text{parameters}})$ </b></summary>
#
# |Souces| Syntax| outputs|
# |--|--|--|
# |Uniform Distribution| ```random.uniform(low, high, size=)```| Draw samples from a uniform distribution|
# | Binomial  | ```binomial(n, p, size)```|Draw samples from a binomial distribution.|
# | normal  | ```normal(loc, scale, size)```|Draw samples from a normal distribution.|
# | Standard normal  | ```standard_normal( size)```|Draw samples from a standard normal distribution.|
# | chi-square  | ```chisquare(df, size```)|Draw samples from a chi-square distribution.|
# | standard student's t  | ```standard_t(df, size)```|Draw samples from a standard student's t distribution.|
# | F  | ```f(dfn, dfd, size)```|Draw samples from a standard student's t distribution.|
# |1-D array ```a``` |```choice(a, size, replace, p, axis, shuffle)```|Generates a random sample from a given array|
#
#
# </details>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖 **$\color{blue}{\textbf{Lab Work:}}$ Create and vidualize Samples by sampling with Uniform, Binomial, and Normal Distributions**

# %% [markdown]
# ---
# ### **Simulations of the distributions of random Sample data as a function of Number of size from $\color{red}{\textbf{integers}}$ or decimals and compare with theoretical distribution (uniform)**
#
# ### Syntax from Uniform Distribution
#
# ###`random.uniform(low, high, size=)`

# %%
import numpy as np
from plotly.figure_factory import create_distplot

sample_size = 40
bin_size = 0.1

population = np.random.uniform(
    low=0,
    high=100,
    size=100000
)

sample = np.random.choice(
    population,
    size=sample_size,
    replace=False
)

# Create an interactive plot
fig = create_distplot(
    [sample], # if you have more than one data set, use commas to separate each set
    group_labels=["Sample from Uniform Distribution"],
    curve_type="kde", # theoretical curve
    show_rug=False,
    bin_size=bin_size, # size of group
    colors=["purple"]
)
fig.update_layout(
    width=950,
    height=500,
    title=f"Sample Distribution with sample size = {sample_size}",
    title_x=0.5,
    xaxis_title="Random Variable X",
    yaxis_title="Probability f(X)",
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ####🧚 **$\color{orange}{\textbf{Notice:}}$** Start the slider at the 0 position and move slowly toward 1000 to oberve how the histogram of sampling from integers remains the same like uniform distribution.
# ####🧚 **$\color{orange}{\textbf{Notice:}}$**  The smaller the bin size is, the closer the samples to Uniform Distribution

# %%
# @title Random Sample from a Uniform Distribution {"run":"auto"}
# @markdown Use the sliders to select the sample size and the bin size
sample_size = 1000 # @param {"type":"slider","min":2,"max":1000,"step":2}
bin_size = 1.05 # @param {"type":"slider","min":0.05,"max":5,"step":0.05}

population = np.random.uniform(
    low=0,
    high=100,
    size=100000
)

sample = np.random.choice(
    population,
    size=sample_size,
    replace=False
)

# Create an interactive plot
fig = create_distplot(
    [sample], # if you have more than one data set, use commas to separate each set
    group_labels=["Sample from Uniform Distribution"],
    curve_type="kde", # theoretical curve
    show_rug=False,
    bin_size=bin_size, # size of group
    colors=["purple"]
)
fig.update_layout(
    width=950,
    height=500,
    title=f"Sample Distribution with sample size = {sample_size}",
    title_x=0.5,
    xaxis_title="Random Variable X",
    yaxis_title="Probability f(X)",
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ---
# ### **Simulations of the distributions of random Sample data as a function of Number of size from $\color{red}{\textbf{a binomial distribtuion}}$ and compare with theoretical curve**
#
# ### Syntax for sampling from binomial distribution
#
# ###`binomial(n, p, size)`

# %%
# @title Random Sample from a Binomial Distribution {"run":"auto"}
# @markdown Use the sliders to select the sample size and the bin size
sample_size = 850 # @param {"type":"slider","min":2,"max":1000,"step":2}
bin_size = 1 # @param {"type":"slider","min":0.05,"max":5,"step":0.05}

population = np.random.binomial(
    n=11,
    p=0.3,
    size=100000
)

sample = np.random.choice(
    population,
    size=sample_size,
    replace=False
)

# Create an interactive plot
fig = create_distplot(
    [sample], # if you have more than one data set, use commas to separate each set
    group_labels=["Sample from Binomial Distribution"],
    curve_type="kde", # theoretical curve
    show_rug=False,
    bin_size=bin_size, # size of group
    colors=["green"]
)
fig.update_layout(
    width=950,
    height=500,
    title=f"Sample Distribution with sample size = {sample_size}",
    title_x=0.5,
    xaxis_title="Random Variable X",
    yaxis_title="Probability f(X)",
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ####🧚 **$\color{orange}{\textbf{Notice:}}$** Start the slider at the 0 position and move slowly toward 1000 to oberve how the histogram of the sampling from a binomial distribution is approaching the normal density function curve.

# %% [markdown]
# ### 🧚 **$\color{green}{\textbf{TO DO:}}$**
# ### **Simulations of the distributions of random Sample data as a function of Number of size from $\color{red}{\textbf{a normal}}$ and compare with theoretical curve**
#
# ### Syntax for sampling from normal distribution
#
# ###`normal(loc, scale, size)`

# %% [markdown]
# #### **1.** Copy and modify the code above to create a similar simulations of the $\color{red}{\textbf{normal}}$ distribution.
# #### **2.** Change the distribution in the title to "Normal`.
# #### **3.** Change the code`binomial(n, p, size)` by `normal(loc, scale, size)` with your choice of a value for loc (mean) and a positive value of scale = standard deviation for a normal distribution.

# %%
# @title Random Sample from a Normal Distribution {"run":"auto"}
# @markdown Use the sliders to select the sample size and the bin size
sample_size = 860 # @param {"type":"slider","min":2,"max":1000,"step":2}
bin_size = 2 # @param {"type":"slider","min":0.05,"max":5,"step":0.05}
import scipy.stats as stats
import plotly.graph_objects as go

std = 5
mu = 0

x_min = mu - 5 * std # Spread to the left by five standard deviations
x_max = mu + 5 * std # Spread to the right by five standard deviations

# Create a list of values of the random variable between `x_min` and `x_max`
# The more points we have, the smoother the pdf curve will be
x_pdf = np.arange(
    x_min,
    x_max,
    0.01 # Resolution
)

# Calculate the y-values with pdf (Probability Density Function) for each value of a
# random variable in the previously defined list. This is distribution dependent.
y_pdf = stats.norm.pdf(
    x=x_pdf, # list of values of the random variable
    loc=mu, # location of the center
    scale=std # Spread of the curve
)

population = np.random.normal(
    loc=mu,
    scale=std,
    size=100000
)

sample = np.random.choice(
    population,
    size=sample_size,
    replace=False
)

# Create an interactive plot
fig = create_distplot(
    [sample], # if you have more than one data set, use commas to separate each set
    group_labels=["Sample from Normal Distribution"],
    curve_type="kde", # theoretical curve
    show_rug=False,
    bin_size=bin_size, # size of group
    colors=["green"]
)
fig.add_trace(
    go.Scatter(
        x=x_pdf, # x-coordinate for the plot
        y=y_pdf, # y-coordinate for the plot
        mode="lines",
        line_color="black"
    )
)
fig.update_layout(
    width=950,
    height=500,
    title=f"Sample Normal Distribution with sample size = {sample_size}",
    title_x=0.5,
    xaxis_title="Random Variable X",
    yaxis_title="Probability f(X)",
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 🧚 **$\color{green}{\textbf{TO DO:}}$** Use the slider to observe the comparison of the histogram to the normal distribution curve as the sample sizes increase.  Write a short paragram to summarize your observation

# %% [markdown]
# In my code above, I added a trace to my graph to show the normal distribution (in black) compared to the randomly generated sample, which is in green. As the sample size in our graph increases, we see that the randomly generated sample more closely approximates the normal distribution, which is to be expected. When a sample size is smaller, we can expect to occasionally see sample distributions that deviate from the expected distribution (for example, if you flip a fair coin, you may get 3-4 heads in a row), but as you increase your sample size, the distribution tends to more closely conform to the expected distribution.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # **Bernolli Experiments and Using the Normal Distribution to Approximate the Binomial Distribution**
#
# <details>
# <summary><b>Review Binomial Experiments and Binomial Distribution</b></summary>
#
# * ### *Bernoulli Trial:* A binomial trial is an experiment for yes or no questions with two boolean answers: success or failure with probability $p$, and $q = 1-p$ ($p+q=1$), respectively
#
# * ### *A binomial variable $X$:* is a discrete variable with binomial distribution $B(n,p)$ the value of the number of successes (or failures) of $n$ Bernoulli experiments (trials).
# $$X\sim B(n,p)$$
# * ### *Binomial probability mass function* equals to the probability of getting exactly $k$ successes in $n$ independent Bernoulli trials (with the same probability of success p)
# $$\text{Pr}(k;n, p)=\begin{pmatrix}n\\k\end{pmatrix}p^k(1-p)^{n-k}$$
# where
# $$\begin{pmatrix}n\\k\end{pmatrix} = \frac{n!}{k!(n-k)!}$$
# <details>

# %% [markdown]
# ## **Using the Normal Distribution to Approximate the Binomial Distribution**
#
# ###**Requirements**
# 1. The sample is a simple random sample of size $n$ from a population in which the proportion of successes is $p$, or the sample is the result of conducting n independent trials of a binomial experiment in which the probability of success is $p$ and the probability of failure is $q$.
#
# 2. $np \geq 10$ and $nq \geq 10$.
#
# ###**Mean and Standard deviation we use for the normal distribution**
#
# > • $\mu = np$
#
# > • $\sigma = \sqrt{npq}$
#
#
# ### **Continuity Correction**
# When using the normal approximation, adjust the discrete whole number x by using a continuity correction so that x is represented by the interval from $x - 0.5$ to $x + 0.5$.  We are in essence creating a "fake bar".

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **🔖 $\color{blue}{\textbf{Lab Work 3 - 5: }}$** Use the normal to approximate the binomial distribution. A costume company claims that 30% of children dress as their favorite movie characters for Halloween in a random sample of 40 children.

# %% [markdown]
# ### **1. Define the Bernoulli Experiment parameters and binomial mass probability distributions:**
# * The definition of success:
# * The probability of success $p = $
# * Total number of experiments $n =$
# * Define the random variable with Binomial probability mass function in Mathematical Notation
# $$X\sim B(n, p))$$

# %% [markdown]
# - The definition of success: A child dresses as their favorite movie character for Halloween
# - The probability of success p = 0.3
# - Total number of experiments n = 40
# - Define the random variable with Binomial probability mass function in Mathematical Notation
# $$X\sim B(40, 0.3))$$

# %%
# Parameters for Bernoulli Experiment
p = 0.3
n = 40

# %% [markdown]
# #### **2. Test for validity of normal distribution and find the parameters of the Normal Distribution to approximate binomial distribution, if valid**
# * **Test for condition**
# $$np \ge 10$$
# $$n(1-p) \ge 10$$
# Conclusion:
# * **Compute Normal distribution parameters and write the Normal distribution in Mathematical Notation:** mean $\mu$ and standard deviation $\sigma$:
# # Note: I believe this formula originally had a typo, it originally had $\mu = p$, but in lab 4.2 part 1, the formula is given as $\mu = np$, so I have modified it here
#  $\mu = np $
#
#  $\sigma = \sqrt{np(1-p)}=$
# * **The random variable with Normal Approximation**

# %% [markdown]
# * **Test for condition**
# $$np \ge 10$$
# $$40 \cdot 0.3 = 12 \geq 10$$
#
# $$n(1-p) \ge 10$$
# $$40(1-0.3) = 28 \geq 10$$
# Conclusion: The parameters given meet the requirements for the Bernoulli Experiment
#
# * **Compute Normal distribution parameters and write the Normal distribution in Mathematical Notation:** mean $\mu$ and standard deviation $\sigma$:
#
#  $\mu = 40 \cdot 0.3 = 12 $
#
#  $\sigma = \sqrt{np(1-p)}= 2.8983$
# * **The random variable with Normal Approximation**

# %%
# Validate that np >= 10
assert n * p >= 10
assert n * (1 - p) >= 10

mean = n * p
std = np.sqrt(n * p * (1 - p))
print(f"Mu and sigma are equal to: {mean} & {std:.4f}")
# Out:
# Mu and sigma are equal to: 12.0 & 2.8983

# %%
"""
In this section, I am borrowing code from the lab work in Lab 4.2 Part I
"""

k = np.arange(0, n+1) # create the sequence of numbers of k from 0 to n exclude n + 1

# compute the probability for each k
probability_k = stats.binom.pmf(
    k = k, # sequence of k
    n = n,
    p = p
)

# Create a list of random values for our variable (input)
x_pdf = np.arange(mean - 5 * std, mean + 5 * std, 0.01)
# Compute the probability density function value for each input value
y_pdf = stats.norm.pdf(x_pdf, mean, std)

fig = go.Figure()

# add binomial distribition
fig.add_trace(
    go.Bar(
        x = k,
        y = probability_k, # for horizontal bar graph, interchange x and y
        marker_color = "rgba(232, 223, 165, 0.5)",
        name = "Binomial distribution"
        )
    )

# add a vertical line for the mean
fig.add_trace(
    go.Scatter(
        x=[mean,mean],
        y=[0,stats.binom.pmf(k = mean, n = n, p = p)],
        mode='lines',
        line=dict(
            color='red',
            width=4,
            dash='dash'
        ),
        name='mean'
    )
)

# Plot the normal distribution as a curve
fig.add_trace(
    go.Scatter(
        x=x_pdf,
        y=y_pdf,
        mode="lines",
        line_color="magenta",
        name="Normal Distribution Approximation"
    )
)

fig.add_trace(
    go.Scatter(
        x=k,
        y=stats.norm.pdf(k, mean, std),
        mode="markers",
        marker_color="chartreuse",
        name="Values with Normal Approximation"
    )
)

fig.update_layout(
    width = 1000, height = 500,
    title = f"Binomial Distribution B(n, p) = B({n}, {p})",
    title_x = 0.5,
    yaxis_title = "Probability Mass Function (pmf)",
    xaxis_title = "Number of Success",
    xaxis_tickangle = 0,
    showlegend = True,
    plot_bgcolor = "dodgerblue"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **🔖 $\color{blue}{\textbf{Lab Work 4: }}$** Compare the values of probabilities using binomial distributions and its normal approximation of 11 success (11 children dress as their favorite movie characters for Halloween.)

# %% [markdown]
# #### **Normal Distribution using pdf**

# %%
# Apply a continuity correction so that x is represented by the interval from x−0.5 to x+0.5
lower_correction = (10.5 - mean) / std
upper_correction = (11.5 - mean) / std
prob_approx_11 = stats.norm.cdf(upper_correction) - stats.norm.cdf(lower_correction)
print(f"The normal distribution probability is: {prob_approx_11:.6f}")
print("This closely matches what is shown in the chart above at 11")
# Out:
# The normal distribution probability is: 0.003848
# This closely matches what is shown in the chart above at 11

# %% [markdown]
# ### **Use the actual binomial probability mass function $P(k = 11)$**.

# %%
binom_prob_11 = stats.binom.pmf(k=11, n=40, p=0.3)
print(f"The binomial distribution probability P(k = 11) is: {binom_prob_11:.6}")
print("This matches exactly to what our chart above shows at 11")
# Out:
# The binomial distribution probability P(k = 11) is: 0.131864
# This matches exactly to what our chart above shows at 11

# %% [markdown]
# #### **Conclusion:** The results are very close

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **🔖 $\color{blue}{\textbf{Lab Work 5: }}$** Graph the binomial distribution and its normal approximation.

# %% [markdown]
# ### **Overlay normal approximation of the binomial distribution**

# %%
p = 0.3
n = 40

mean = n * p
std = np.sqrt(n * p * (1 - p))

k = np.arange(0, n+1) # create the sequence of numbers of k from 0 to n exclude n + 1

# compute the probability for each k
probability_k = stats.binom.pmf(
    k = k, # sequence of k
    n = n,
    p = p
)

# Create a list of random values for our variable (input)
x_pdf = np.arange(mean - 5 * std, mean + 5 * std, 0.01)
# Compute the probability density function value for each input value
y_pdf = stats.norm.pdf(x_pdf, mean, std)

fig = go.Figure()

# add binomial distribition
fig.add_trace(
    go.Bar(
        x = k,
        y = probability_k, # for horizontal bar graph, interchange x and y
        marker_color = "rgba(232, 223, 165, 0.5)",
        name = "Binomial distribution"
        )
    )

# add a vertical line for the mean
fig.add_trace(
    go.Scatter(
        x=[mean,mean],
        y=[0,stats.binom.pmf(k = mean, n = n, p = p)],
        mode='lines',
        line=dict(
            color='red',
            width=4,
            dash='dash'
        ),
        name='mean'
    )
)

# Plot the normal distribution as a curve
fig.add_trace(
    go.Scatter(
        x=x_pdf,
        y=y_pdf,
        mode="lines",
        line_color="magenta",
        name="Normal Distribution Approximation"
    )
)

fig.add_trace(
    go.Scatter(
        x=k,
        y=stats.norm.pdf(k, mean, std),
        mode="markers",
        marker_color="chartreuse",
        name="Values with Normal Approximation"
    )
)

fig.update_layout(
    width = 1000, height = 500,
    title = f"Binomial Distribution B(n, p) = B({n}, {p}) with Normal Distribution overlaid",
    title_x = 0.5,
    yaxis_title = "Probability Mass Function (pmf)",
    xaxis_title = "Number of Success",
    xaxis_tickangle = 0,
    showlegend = True,
    plot_bgcolor = "dodgerblue"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 🧚 **$\color{green}{\textbf{TO DO 4:}}$** Bernolli Experiments and Normal Approximation of Binomial Distributions:
#
# #### **Answer the following questions using this problem: with the following problem**
#
# #### The American Automobile Association claims that 54% of fatal car/truck accidents are caused by driver error. A researcher studies 35

# %% [markdown]
# ### **1. Define the Bernoulli Experiment parameters and binomial mass probability distributions:**
# * The definition of success: A fatal car/truck accident is caused by driver error
# * The probability of success $p = 0.54$
# * Total number of experiments $n = 35$
# * Define the random variable with Binomial probability mass function in Mathematical Notation
# $$X\sim B(35, 0.54)$$

# %% [markdown]
# #### **2. Test for validity of normal distribution and find the parameters of the Normal Distribution to approximate binomial distribution, if valid**
# * **Test for condition**
# $$np \ge 10$$
# $$n(1-p) \ge 10$$
# Conclusion:
# * **Compute Normal distribution parameters and write the Normal distribution in Mathematical Notation:** mean $\mu$ and standard deviation $\sigma$:
#
#  $\mu = p$
#
#  $\sigma = \sqrt{np(1-p)}=$
# * **The random variable with Normal Approximation**

# %%
# @title Random Variable with Normal Approximation {"run":"auto"}
k = 20 # @param {"type":"slider","min":5,"max":35,"step":1}
n = 35
p = 0.54
# Assertion statements can be used to validate that the conditions to approximate the binomial distribution are valid
assert n * p >= 10
assert n * (1 - p) >= 10

mean = n * p
std = np.sqrt(n * p * (1 - p))
# Create a list of random values for our variable (input)
x_pdf = np.arange(mean - 5 * std, mean + 5 * std, 0.01)
# Compute the probability density function value for each input value
y_pdf = stats.norm.pdf(x_pdf, mean, std)

fig = go.Figure()

# Plot the normal distribution as a curve
fig.add_trace(
    go.Scatter(
        x=x_pdf,
        y=y_pdf,
        mode="lines",
        line_color="magenta",
        name="Normal Distribution Approximation"
    )
)

y_k = stats.norm.pdf(k, mean, std)  # pdf at x = k

# Add a single point (marker) on the curve
fig.add_trace(
    go.Scatter(
        x = [k],
        y = [y_k],
        mode = 'markers',
        marker=dict(color='red', size=8),
        name = f'Probability at x={k}: {y_k:.1%})'
    )
)

fig.update_layout(
    width = 1000, height = 500,
    title = f"Random Variable Normal Approximation",
    title_x = 0.5,
    yaxis_title = "Probability Mass Function (pmf)",
    xaxis_title = "Number of Success",
    xaxis_tickangle = 0,
    showlegend = True,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **3. Choose a number of successes to compute its probability using actual Binomial distribution and its normal approximation. (Choose a different value of success if the probability is 0)**

# %% [markdown]
# #### **Normal Distribution using pdf**

# %%
k = 18
n = 35
p = 0.54
mean = n * p
std = np.sqrt(n * p * (1 - p))

# Apply a continuity correction so that x is represented by the interval from x−0.5 to x+0.5
lower_correction = (k - .5 - mean) / std
upper_correction = (k + .5 - mean) / std
prob_approx_11 = stats.norm.cdf(upper_correction) - stats.norm.cdf(lower_correction)
print(f"The normal distribution probability is: {prob_approx_11:.6f}")
print("This closely matches what is shown in the chart above at 11")

binom_prob_11 = stats.binom.pmf(k=k, n=n, p=p)
print(f"The binomial distribution probability P(k = 11) is: {binom_prob_11:.6}")
print("This matches exactly to what our chart above shows at 11")
# Out:
# The normal distribution probability is: 0.128583
# This closely matches what is shown in the chart above at 11
# The binomial distribution probability P(k = 11) is: 0.127877
# This matches exactly to what our chart above shows at 11

# %% [markdown]
# ### **Use the actual binomial probability mass function $P(k = 20)$**.

# %%
k = 20
# compute the probability for each k
probability_k = stats.binom.pmf(
    k = k, # sequence of k
    n = n,
    p = p
)
print(f"The probability mass function P(k={k}): {probability_k:.6f}")
# Out:
# The probability mass function P(k=20): 0.126139

# %% [markdown]
# ### **4. Plot the binomial distribution and its normal approximation both as scatter plots and line plots with mean similar to Lab 5. (Choose a different value of success if the probability is 0)**

# %%
n = 35
p = 0.54

mean = n * p
std = np.sqrt(n * p * (1 - p))

k = np.arange(0, n+1) # create the sequence of numbers of k from 0 to n exclude n + 1

# compute the probability for each k
probability_k = stats.binom.pmf(
    k = k, # sequence of k
    n = n,
    p = p
)

# Create a list of random values for our variable (input)
x_pdf = np.arange(mean - 5 * std, mean + 5 * std, 0.01)
# Compute the probability density function value for each input value
y_pdf = stats.norm.pdf(x_pdf, mean, std)

fig = go.Figure()

# add binomial distribition
fig.add_trace(
    go.Bar(
        x = k,
        y = probability_k, # for horizontal bar graph, interchange x and y
        marker_color = "rgba(232, 223, 165, 0.5)",
        name = "Binomial distribution"
        )
    )

# add a vertical line for the mean
fig.add_trace(
    go.Scatter(
        x=[mean,mean],
        # The mean is shown at the actual value (18.9) instead of rounded off to the nearest integer
        y=[0, stats.norm.pdf(mean, mean, std)],
        mode='lines',
        line=dict(
            color='red',
            width=4,
            dash='dash'
        ),
        name='mean'
    )
)

# Plot the normal distribution as a curve
fig.add_trace(
    go.Scatter(
        x=x_pdf,
        y=y_pdf,
        mode="lines",
        line_color="magenta",
        name="Normal Distribution Approximation"
    )
)

fig.add_trace(
    go.Scatter(
        x=k,
        y=stats.norm.pdf(k, mean, std),
        mode="markers",
        marker_color="chartreuse",
        name="Values with Normal Approximation"
    )
)

fig.update_layout(
    width = 1200, height = 600,
    title = f"Binomial Distribution B(n, p) = B({n}, {p}) with Normal Distribution overlaid",
    title_x = 0.5,
    yaxis_title = "Probability Mass Function (pmf)",
    xaxis_title = "Number of Success",
    xaxis_tickangle = 0,
    showlegend = True,
    plot_bgcolor = "dodgerblue"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
