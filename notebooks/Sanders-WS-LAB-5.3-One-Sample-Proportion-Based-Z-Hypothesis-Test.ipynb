# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# $$\Large \textbf{ Hypothesis Test 2: }\color{violet}{\text{ Z-test }}$$
#
# ---
# ###  **Test Base:** Proportion-Based
# ###  **Number of Samples:** One Sample
# ###  **Test Distribution:**  $X \sim N(\mu, \sigma)$ Normal Distribution as approximation of $n$ binomial trails Binomial Trials $P' \sim B(n, p)$.
# ---

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Definition of Proportion Test, Distributions, and Assumptions**

# %% [markdown]
# <details>
#   <summary><b> Description of Hypothesis Testing of Proportion-Based Samples</b></summary>
#
# In the hypothesis tests of proportion-based samples we’re interested in checking proportions. For example 17% of a sample matches some profile, and the rest does not. This could be a test comparing a single sample against some expected value, or comparing two different samples.
#
# Note: These tests are only valid when there are only two possible options; and if the probability of one option is $\mathbf{p}$, then the probability of the other must be $\mathbf{(1 – p)}$.
#
# </details>
#
# <details>
#   <summary><b> Assumptions</b></summary>
#
# Required sampling Rules for Proportion-Based Hypothesis Tests:
#
#
# #### **Normal:** The sample must reflect the distribution of the underlying population. For these tests a good rule of thumb is that:
# * Given a sample size of $\mathbf n$
# * Given a sample proportion of $\mathbf p$
# * Then both $\mathbf{np}$ and $\mathbf{n(1-p)}$ must be at least $\mathbf{10}$
#
# #### **Independence:** The "independence" requirement in a hypothesis test for a proportion in one population relates to the selection and relationship of the data points within the sample being tested. Specifically, it encompasses two main criteria:
#
# 1. **Random Sampling**: The data must be collected in a way that every individual in the population has an equal chance of being included in the sample. This ensures that the sample is representative of the population, reducing bias and making the results of the test more generalizable to the population as a whole.
#
# 2. **Individual Observations Independence**: Each observation in the sample must be independent of the others. This means that the outcome of one observation does not influence or is not influenced by the outcome of another observation. In practical terms, this often translates to the requirement that the sample size is less than 10% of the population (the "10% condition"), to minimize the chances of picking from a depleted population without replacement, which could violate independence.
#
# These requirements are crucial for the validity of the hypothesis test. They ensure that the statistical methods used to estimate the population parameters and calculate p-values or confidence intervals are based on sound principles, leading to reliable and accurate conclusions. The independence requirement, in particular, underpins many of the probability calculations that allow statisticians to infer about the population from the sample data. Without independence, the standard errors, confidence intervals, and significance tests derived from the sample could be misleading or incorrect.
#
# </details>

# %% [markdown]
# ---
# ## **Summary Normal Distribution Approximation of One Sample from Repeated Binomial Trials**

# %% [markdown]
# |Terms|Validtions and Parameters and Validations||
# |--|--|--|
# |Condition|1. $n$ is large <br> 2. Your data should be a <b> single random sample </b> <br>   that comes from a population.<br> 3. The outsome of each trial is a binomial distrbution:<br>with the same probability of success $\hat{p}$.  <br> 4. $n\hat{p} \geq 10$ and $n\hat{q} = n(1-\hat{p}) \geq 10$ <br>|
# |Population Proportion| $\hat{p}$|
# |standard deviation| $std = \sqrt{\frac{\hat{p}(1 - \hat{p})}{n}}$|
# |Normal Distribution Approximation|$ P\prime \sim N(\hat{p}, std)$
# |Point of Estimate| $\hat{p} =\frac{x}{n}$<br> Where <br>$x$ is the number of successes and <br>$n$ is the sample size.

# %% [markdown]
# ---
#
# ## **Python `statsmodels` syntax for Proportion-Based 1-Sample $\color{violet}{\text{ Z-test }}$**

# %% [markdown]
# ###  Syntax `statsmodels.stats.proportion.proportions_ztest(count, nobs, value=None, alternative='two-sided', prop_var=False)`
#
#
# Test for proportions based on normal (z) test. For more information click [here](https://www.statsmodels.org/devel/generated/statsmodels.stats.proportion.proportions_ztest.html).
#
# <details>
#   <summary><b>Show Specifications of Parameters</b></summary>
#
# This is a test for the null hypothesis that the expected value (mean) of a sample of independent observations a is equal to the given population mean, popmean.
#
# **Parameters**
#
# **count: {int, array_like},** the number of successes in nobs trials. If this is array_like, then the assumption is that this represents the number of successes for each independent sample
#
# **nobs: {int, array_like}**
#   the number of trials or observations, with the same length as count.
#
# **value:** float, array_like or None, optional
#   This is the value of the null hypothesis equal to the proportion in the case of a one sample test. In the case of a two-sample test, the null hypothesis is that prop[0] - prop[1] = value, where prop is the proportion in the two samples. If not provided value = 0 and the null is prop[0] = prop[1]
#
# **alternative:** str in [‘two-sided’, ‘smaller’, ‘larger’]
#   The alternative hypothesis can be either two-sided or one of the one- sided tests, smaller means that the alternative hypothesis is prop < value and larger means prop > value. In the two sample test, smaller means that the alternative hypothesis is p1 < p2 and larger means p1 > p2 where p1 is the proportion of the first sample and p2 of the second one.
#
# **prop_var:** False or float in (0, 1)
#   If prop_var is false, then the variance of the proportion estimate is calculated based on the sample proportion. Alternatively, a proportion can be specified to calculate this variance. Common use case is to use the proportion under the Null hypothesis to specify the variance of the proportion estimate.
#
# **Returns**
#
# **zstat:** float, test statistic for the z-test
#
# **p-value:** float, p-value for the z-test
# </details>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## 🔖 **$\color{blue}{\textbf{Lab Work 1: }}$ 1-Sample $\color{purple}{\text{two-sided}}$ Z-Test**
#
# ### ```statsmodels.stats.proportion.proportions_ztest(count, nobs, value=None, alternative='two-sided', prop_var=False)```
#
#
# Test for proportions based on normal (z) test. For more information click [here](https://www.statsmodels.org/devel/generated/statsmodels.stats.proportion.proportions_ztest.html).
#
# <details>
#   <summary><b>Show Specifications of Parameters</b></summary>
#
# This is a test for the null hypothesis that the expected value (mean) of a sample of independent observations a is equal to the given population mean, popmean.
#
# **Parameters**
#
# **count: {int, array_like},** the number of successes in nobs trials. If this is array_like, then the assumption is that this represents the number of successes for each independent sample
#
# **nobs: {int, array_like}**
#   the number of trials or observations, with the same length as count.
#
# **value:** float, array_like or None, optional
#   This is the value of the null hypothesis equal to the proportion in the case of a one sample test. In the case of a two-sample test, the null hypothesis is that prop[0] - prop[1] = value, where prop is the proportion in the two samples. If not provided value = 0 and the null is prop[0] = prop[1]
#
# **alternative:** str in [‘two-sided’, ‘smaller’, ‘larger’]
#   The alternative hypothesis can be either two-sided or one of the one- sided tests, smaller means that the alternative hypothesis is prop < value and larger means prop > value. In the two sample test, smaller means that the alternative hypothesis is p1 < p2 and larger means p1 > p2 where p1 is the proportion of the first sample and p2 of the second one.
#
# **prop_var:** False or float in (0, 1)
#   If prop_var is false, then the variance of the proportion estimate is calculated based on the sample proportion. Alternatively, a proportion can be specified to calculate this variance. Common use case is to use the proportion under the Null hypothesis to specify the variance of the proportion estimate.
#
# **Returns**
#
# **zstat:** float, test statistic for the z-test
#
# **p-value:** float, p-value for the z-test
# </details>

# %% [markdown]
# <details>
#   <summary><b> Show the problem </b></summary>
#
# Joon believes that 50% of first-time brides in the United States are younger than their grooms. She performs a hypothesis test to determine if the percentage is <b> the same or different </b> from 50%. Joon samples <b> 100 first-time brides </b> and <b> 53 </b>
# replies that they are younger than their grooms. For the hypothesis test, she uses a 1% level of significance.
#
# </details>

# %% [markdown]
# ### **1. Set up the hypotheses.**

# %% [markdown]
# $H_o: p=0.5$
#
# $H_a: p\ne0.5$ (can be greater or less, but not equal to 0.5, this is a two-tailed test)

# %% [markdown]
# ### **2.** Are the conditions $\mathbf{np} \ge \mathbf{10}$ and $\mathbf{n(1-p)} \ge \mathbf{10}$ met?

# %%
n = 100
p_hat = 0.53 # Success of the sample, not the population
# This will equal `53 >= 10`
assert n * p_hat >= 10
# This will equal `47 >= 10`
assert n * (1 - p_hat) >= 10
# Both conditions are satisfied

# %% [markdown]
# ### **3. Choose the distribution and parameters.**

# %% [markdown]
# The problem contains no mention of a mean. Therefore, this is a proportion-based one sample test. The sample size is large enough to use a normal distribution to approximate the binomial trials of a sample of size 100.
#
# **Random Variable**: $P^\prime$ is the proportion of first time brides who are younger than their grooms.
#
# $P^\prime \sim N\left(p, \sqrt{\frac{p(1 - p)}{n}} \right)$
#
# $P^\prime \sim N\left(0.5, \sqrt{\frac{0.5(1 - 0.5)}{100}} \right)$ where $p=0.5, q = 1 - p$ and $n = 100$

# %% [markdown]
# ### **4. Calculate the test statistic and $p$ value for 1-Sample Two-Sided Z-Test.**

# %%
from statsmodels.stats.proportion import proportions_ztest

sample_success = 53
sample_size = 100
p_null = 0.5 # null hypothesis
alpha = 0.01
test_type = "two-sided"

# Output z_stat and p_value
z_stat, p_value = proportions_ztest(
    count=sample_success, # number of successes in the sample
    nobs=sample_size, # number of observations
    value=p_null, # value is the null hypothesis, or population proportion
    alternative=test_type,
    prop_var=False # false means to use sample data for variance
)
print(f"The z-statistic of the test = {z_stat} and p-value = {p_value}")
# Out:
# The z-statistic of the test = 0.6010829247756464 and p-value = 0.5477847557024209

# %% [markdown]
# ### **5:  Make a decision about $H_0$ by comparing the $p$ values and statistical significance level $\alpha$**

# %% [markdown]
# Based on our p-value of $0.5477847557024209 \gt 0.01$ (statistically significant level), the sample data fails to reject the null hypothesis

# %% [markdown]
# ### **6. Write a conclusion about the hypothesis test.**

# %% [markdown]
# There is not enough evidence to reject the null hypothesis. At the 1% statistical significance, the sample data do not show sufficient evidence that the percentage of the first-time brides who are younger than their groom is different from 50%
#
# Another way to phrase this is that there is insufficient evidence to warrant rejection of the original claim at the 0.01 statistical significance level.

# %% [markdown]
# ### **7. Write about any possible sources of error of other factors that could affect the results of our hypothesis tests.**

# %% [markdown]
# 1. We do not know where the data comes from, the data could be biased.
# 2. The sample size or the $\alpha$ value may be incorrect

# %% [markdown]
# ### **8. Graph the distribution and $p$-value.**
# >> * #### **Hint 1:** If the inputs below you enter agree with the parameter variables used in creating the plot, you should see a plot with arrows pointing to the critical values at the statistically significant level $\alpha$ and test statistic, respectively.
#
# >> * #### **Hint 2:** Use as many decimal places as possible.
#
# >> * #### **Hint 3:** If you do not enter the correct p values or type of the hypothesis test, the App will output a message and exit.

# %%
#@title Enter the values for the hypothesis test from your computation above
# @markdown Enter the number of sunccess of the sample
x_success_sample = 53 #@param {type:"number"}
# @markdown Enter the sample size $n$
n = 100 #@param {type:"integer"}
# @markdown Enter the <font color = "red"> probability of success of each binomial trial </font><br>(proportion for the $H_0$ Hypothesis)
p_null = 0.5 #@param {type:"number"}
# @markdown Enter the <font color = "red"> p value </font> from your hypothesis test with at least seven decimal places)
p_value = 0.5477847557024209 #@param {type:"number"}
#@markdown Choose the probability distribution you used for this hypothesis testing
p_distribution = "Normal Distribution" # @param ["Normal Distribution", "Student's t Distribution", "Chi-Square Distribution","f Distribution", "None"]
#@markdown Choose the type of this hypothesis testing
Test_types = "Two-tailed hypothesis test" # @param ["Left-tailed hypothesis test", "Right-tailed hypothesis test", "Two-tailed hypothesis test","None"]
# @markdown Enter the statistically significant level
alpha = 0.01 #@param {type:"number"}

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats  as stats
import sys # at top of file
# %matplotlib inline


# input value of the ransom variable and parameters of the normal distribution
# x_low < X < x_high: value of the random variable with a normal distribution
mu = p_null                # mean
std = np.sqrt(mu * (1 - mu) /n)             # standard deviation

# compute the higher limit of proportion

p_sample = x_success_sample / n # sample proportion of success

# find where p_sample is on the left or right of p_null
if (p_sample >= mu ):
  x_high = p_sample
  x_low = mu - (x_high - mu)
else:
  x_low = p_sample
  x_high = mu  + (mu - x_low) # lower proportion for p-value

#Compute the p value for two tailed test
"""
p_value = 2 * stats.norm.cdf(x= x_low,  #value of the random variable
                      loc = mu,    # mean
                      scale= std   # standard deviation
                      )
"""
if ((p_value < 0.547) or (p_value > 0.549)):
    print("The p values was not accurate, check the prameters you entered in STEP 4.")
    print("If you entered the accurate p value, a graph will show.")
    sys.exit()
elif Test_types != "Two-tailed hypothesis test":
    print("The type of hypothesis does not agree with your hypothesis.  Check the proporty of this probability distribution ")
    sys.exit()
elif (p_distribution != "Normal Distribution"):
    print("Reread the problem and chek the sample sizes to see what probability distribution you need to use.")
    sys.exit()
# Plot normal distribution areas*

plt.figure(figsize = (12, 7 ))
x_lower = mu - 4 * std
x_higher = mu + 4 * std

#add the density curve ppf to the plot
x_pdf = np.arange(x_lower, x_higher,0.001) # array of input values for pdf
y_pdf = stats.norm.pdf(x_pdf, loc = mu, scale = std)
plt.plot(x_pdf, y_pdf, color='black', linewidth = 2)

plt.fill_between(x_pdf, y_pdf, where = (x_pdf < x_low ) | ( x_pdf > x_high), facecolor = "lightgreen", alpha = 0.5)

# compute the critical value for a two-tailed test
x_ct = stats.norm.ppf(alpha/2, loc=mu, scale=std)
y_ct = stats.norm.pdf(x_ct, loc = mu, scale = std)

plt.vlines(x_ct, 0, y_ct, colors="red", linestyles='solid', label='critical point', linewidth = 4)

plt.vlines(2 * mu - x_ct, 0, y_ct, colors="red", linestyles='solid', linewidth = 4)

plt.annotate(r'Critical Value at $\alpha/ 2$', xy =(x_ct, 0),
                xytext =(mu - 0.04, 1.8),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)

plt.annotate(r'Critical Value at $\alpha/ 2$', xy =(2 * mu - x_ct, 0),
                xytext =(mu - 0.04, 1.8),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)


plt.annotate(r"$p_{sample}$'s", xy =(x_low, 0),
                xytext =(mu - 0.015, 1.0),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)
plt.annotate(r"$p_{sample}$'s", xy =(x_high, 0),
                xytext =(mu - 0.015, 1.0),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)

y_label = -1.2


plt.text(x = mu - 0.01, y= y_label, s= r"$p_{H_{0}}=$"+f"{mu}", fontsize=12, )


x_text = mu - 3.5 * std
y_text = 3
plt.text(x = mu - 3.5 * std, y= y_text, fontsize=15,
         s = "Shaded area\n represents \n probability \n" + r"$P(p < p_{sample})$" + "\n=(1/2) p-value\n=" + str(round(p_value / 2,5)))
plt.text(x = mu + 2 * std, y= y_text, fontsize=15,
         s = "Shaded area\n represents \n probability \n" + r"$P(p >2p_{H_0} - p_{sample})$" + "\n=(1/2) p-value\n=" + str(round(p_value / 2,5)))
plt.text(mu + 2 * std, y_text - 1, fontsize=15, s =r'$\alpha = $' + str(alpha))

plt.ylabel('Normal Probability Density Function', fontsize = 14)
#plt.legend(loc='best')
plt.xlabel(r"Proportion $P$", fontsize = 14, )


ax = plt.subplot()
ax.set_yticklabels([])
ax.xaxis.set_label_coords(0.5, -0.15)
plt.title("One Population Proportion Hypothesis Test of Binomial Trials\n wuth Normal Approdimation ", fontsize = 14)
plt.show()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## 🔖 **$\color{blue}{\textbf{Lab Work 2:}}$ Left-tailed 1 Proportion Hypothesis Test**

# %% [markdown]
# <details>
# <summary><b>Show problem </b></summary>
#
# Marketers believe that 91% of adults in the United States own a cell phone. A cell phone manufacturer believes that the number is actually lower. 200 American adults are surveyed, of which, 172 report having cell phones. Use a 5% level of significance. State the null and alternative hypotheses, find the p-value, and state your conclusion.
#
# </details>

# %% [markdown]
# ### **1. Set up the hypotheses.**

# %% [markdown]
# $H_o : p = 0.91$
#
# $H_a : p \lt 0.91$
#
# This is a left-tailed test
#
# $\alpha = 0.05$

# %% [markdown]
# ### **2. Are the conditions both $\mathbf{np} \ge \mathbf{10}$ and $\mathbf{n(1-p)} \ge \mathbf{10}$ met?**

# %% [markdown]
# $np_{\text{success}} {sample} = 200 \cdot (172 / 200) = 172 \geq 10$
#
# $n(1 - p_{\text{success}}) (sample) = 200 \cdot (200 - 172)/200 = 28 \geq 10$

# %%
n = 200
p = 0.86 # 172 / 200

# 200 * 0.86 = 172 >= 10
assert n * p >= 10
# 200 * (1 - 0.86) = 28 >= 10
assert n * (1 - p) >= 10

# %% [markdown]
# ### **3. Choose distributions and parameters.**

# %% [markdown]
# The problem contains no mention of a mean. Therefore, this is a proportion-based one sample test. The sample size is large enough to use a normal distribution to approximate the binomial trials of a sample of size 200.
#
# **Random Variable**: $P^\prime$ is the proportion of American adults who own cell phones.
#
# $P^\prime \sim N\left(p, \sqrt{\frac{p(1 - p)}{n}} \right)$
#
# $P^\prime \sim N\left(0.91, \sqrt{\frac{0.91(1 - 0.91)}{200}} \right)$ where $p=0.91, q = 1 - 0.91$ and $n = 200$

# %% [markdown]
# ### **4. Write Python Code to Perform 1-Sample Z-Test.**

# %%
from statsmodels.stats.proportion import proportions_ztest

sample_success = 172
sample_size = 200
p_null = 0.91 # null hypothesis
alpha = 0.05
test_type = "smaller" # represents the left tail

# Output z_stat and p_value
z_stat, p_value = proportions_ztest(
    count=sample_success, # number of successes in the sample
    nobs=sample_size, # number of observations
    value=p_null, # value is the null hypothesis, or population proportion
    alternative=test_type,
    prop_var=False # false means to use sample data for variance
)
print(f"The z-statistic of the test = {z_stat} and p-value = {p_value}")
# Out:
# The z-statistic of the test = -2.037847864848058 and p-value = 0.020782574918655716

# %% [markdown]
# ### **5:  Make a decision about $H_0$ by comparing the $p$ values and statistical significance level $\alpha$**

# %% [markdown]
# Because our $p$ value is $0.020782574918655716 \lt \alpha = 0.05$, the sample shows sufficient evidence to reject the null hypothesis ($H_o$). The test result is statistically significant.

# %% [markdown]
# ### **6. Write a conclusion about the hypothesis test.**

# %% [markdown]
# At the 0.05 statistical significance level, the sample data supports the original claim that less than 91% of American adults have a cell phone.

# %% [markdown]
# ### **7: Write about any possible sources of error or other factors that could affect our hypothesis test.**

# %% [markdown]
# The data that is represented by this sample could be out of date, or the people who were chosen to answer may not be representative of the population at large.

# %% [markdown]
# ### **8. Graph the distribution and $p$-value.**
# >> * #### **Hint 1:** If the inputs below you enter agree with the parameter variables used in creating the plot, you should see a plot with arrows pointing to the critical values at the statistically significant level $\alpha$ and test statistic, respectively.
#
# >> * #### **Hint 2:** Use as many decimal places as possible.
#
# >> * #### **Hint 3:** If you do not enter the correct p values or type of the hypothesis test, the App will output a message and exit.

# %%
#@title Enter the values for the hypothesis test from your computation above
# @markdown Enter the number of sunccess of the sample
x_success_sample = 172 #@param {type:"number"}
# @markdown Enter the sample size $n$
n = 200 #@param {type:"integer"}
# @markdown Enter the <font color = "red"> probability of success of each binomial trial </font><br>(proportion for the $H_0$ Hypothesis)
p_null = 0.91 #@param {type:"number"}
# @markdown Enter the <font color = "red"> p value </font> from your hypothesis test with at least seven decimal places)
p_value = 0.020782574918655716 #@param {type:"number"}
#@markdown Choose the probability distribution you used for this hypothesis testing
p_distribution = "Normal Distribution" # @param ["Normal Distribution", "Student's t Distribution", "Chi-Square Distribution","f Distribution", "None"]
#@markdown Choose the type of this hypothesis testing
Test_types = "Left-tailed hypothesis test" # @param ["Left-tailed hypothesis test", "Right-tailed hypothesis test", "Two-tailed hypothesis test","None"]
# @markdown Enter the statistically significant level
alpha = 0.05 #@param {type:"number"}

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats  as stats
import sys # at top of file
# %matplotlib inline


# input value of the ransom variable and parameters of the normal distribution
# x_low < X < x_high: value of the random variable with a normal distribution
mu = p_null                # mean
std = np.sqrt(mu * (1 - mu) /n)             # standard deviation

# compute the higher limit of proportion

p_sample = x_success_sample / n # sample proportion of success

x_low = p_sample
"""
# find where p_sample is on the left or right of p_null
if (p_sample >= mu ):
  x_high = p_sample
  x_low = mu - (x_high - mu)
else:
  x_low = p_sample
  x_high = mu  + (mu - x_low) # lower proportion for p-value
"""
#Compute the p value for two tailed test
"""
p_value = stats.norm.cdf(x= x_low,  #value of the random variable
                      loc = mu,    # mean
                      scale= std   # standard deviation
                      )
"""
if ((p_value < 0.02) or (p_value > 0.021)):
    print("The p values was not accurate, check the prameters you entered in STEP 4.")
    print("If you entered the accurate p value, a graph will show.")
    sys.exit()
elif Test_types != "Left-tailed hypothesis test":
    print("The type of hypothesis does not agree with your hypothesis.  Check the proporty of this probability distribution ")
    sys.exit()
elif (p_distribution != "Normal Distribution"):
    print("Reread the problem and chek the sample sizes to see what probability distribution you need to use.")
    sys.exit()
# Plot normal distribution areas*

plt.figure(figsize = (12, 7 ))
x_lower = mu - 4 * std
x_higher = mu + 4 * std

#add the density curve ppf to the plot
x_pdf = np.arange(x_lower, x_higher,0.001) # array of input values for pdf
y_pdf = stats.norm.pdf(x_pdf, loc = mu, scale = std)
plt.plot(x_pdf, y_pdf, color='black', linewidth = 2)

plt.fill_between(x_pdf, y_pdf, where = x_pdf < x_low , facecolor = "lightgreen", alpha = 0.5)

# compute the critical value for a two-tailed test
x_ct = stats.norm.ppf(alpha/2, loc=mu, scale=std)
y_ct = stats.norm.pdf(x_ct, loc = mu, scale = std)

plt.vlines(x_ct, 0, y_ct, colors="red", linestyles='solid', label='critical point', linewidth = 4)

#plt.vlines(2 * mu - x_ct, 0, y_ct, colors="red", linestyles='solid', linewidth = 4)

plt.annotate(r'Critical Value at $\alpha$', xy =(x_ct, 0),
                xytext =(mu - 0.03 , 3),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)

plt.annotate(r"$p_{sample}$ = " +f"{x_low}", xy =(x_low, 0),
                xytext =(x_low - 0.025, 3.0),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)
"""
plt.annotate(r'Critical Value at $\alpha/ 2$', xy =(2 * mu - x_ct, 0),
                xytext =(mu - 0.04, 1.8),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)

plt.annotate(r"$p_{sample}}$'s", xy =(x_high, 0),
                xytext =(mu - 0.015, 1.0),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)
"""
y_label = -3


plt.text(x = mu - 0.01, y= y_label, s= r"$p_{H_{0}}=$"+f"{mu}", fontsize=12, )


x_text = mu - 3.5 * std
y_text = 8
plt.text(x = mu - 3.5 * std, y= y_text, fontsize=15,
         s = "Shaded area\n represents \n probability \n" + r"$P(p < p_{sample})$" + "\n= p-value\n=" + str(round(p_value,5)))
"""
plt.text(x = mu + 2 * std, y= y_text, fontsize=15,
         s = "Shaded area\n represents \n probability \n" + r"$P(p >2p_{H_0} - p_{sample})$" + "\n=(1/2) p-value\n=" + str(round(p_value / 2,3)))
"""
plt.text(mu + 2 * std, y_text - 1, fontsize=15, s =r'$\alpha = $' + str(alpha))

plt.ylabel('Normal Probability Density Function', fontsize = 14)
#plt.legend(loc='best')
plt.xlabel(r"Proportion $P$", fontsize = 14, )


ax = plt.subplot()
ax.set_yticklabels([])
ax.xaxis.set_label_coords(0.5, -0.15)
plt.title("One Population Proportion Hypothesis Test of Binomial Trials\n wuth Normal Approdimation ", fontsize = 14)
plt.show()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## 🔖 **$\color{green}{\textbf{ TODO 1: }}$ Perform the appropriate hypothesis test.**
#
# ### ```statsmodels.stats.proportion.proportions_ztest(count, nobs, value=None, alternative='two-sided', prop_var=False)```
#
#
# Test for proportions based on normal (z) test. For more infor click [here](https://www.statsmodels.org/devel/generated/statsmodels.stats.proportion.proportions_ztest.html).
#
# <details>
#   <summary><b>Show Specifications of Parameters</b></summary>
#
# This is a test for the null hypothesis that the expected value (mean) of a sample of independent observations a is equal to the given population mean, popmean.
#
# **Parameters**
#
# **count: {int, array_like},** the number of successes in nobs trials. If this is array_like, then the assumption is that this represents the number of successes for each independent sample
#
# **nobs: {int, array_like}**
#   the number of trials or observations, with the same length as count.
#
# **value:** float, array_like or None, optional
#   This is the value of the null hypothesis equal to the proportion in the case of a one sample test. In the case of a two-sample test, the null hypothesis is that prop[0] - prop[1] = value, where prop is the proportion in the two samples. If not provided value = 0 and the null is prop[0] = prop[1]
#
# **alternative:** str in [‘two-sided’, ‘smaller’, ‘larger’]
#   The alternative hypothesis can be either two-sided or one of the one- sided tests, smaller means that the alternative hypothesis is prop < value and larger means prop > value. In the two sample test, smaller means that the alternative hypothesis is p1 < p2 and larger means p1 > p2 where p1 is the proportion of the first sample and p2 of the second one.
#
# **prop_var:** False or float in (0, 1)
#   If prop_var is false, then the variance of the proportion estimate is calculated based on the sample proportion. Alternatively, a proportion can be specified to calculate this variance. Common use case is to use the proportion under the Null hypothesis to specify the variance of the proportion estimate.
#
# **Returns**
#
# **zstat:** float, test statistic for the z-test
#
# **p-value:** float, p-value for the z-test
# </details>

# %% [markdown]
# <details>
#   <summary><b> Show the problem </b></summary>
#
# According to the US Census, there are approximately 268,608,618 residents aged 12 and older. Statistics from the Rape, Abuse, and Incest National Network indicate that, on average, 207,754 rapes occur each year (male and female) for persons aged 12 and older. This translates into a percentage of sexual assaults of 0.078%. In Daviess County, KY, there were reported 11 rapes for a population of 37,937. Conduct an appropriate hypothesis test to determine if there is a statistically significant difference between the local sexual assault percentage and the national sexual assault percentage. Use a significance level of 0.01.
#
# </details>

# %% [markdown]
# ### **1 Set up the hypotheses.**

# %% [markdown]
# $H_o: p=0.00078$
#
# $H_a: p\ne0.00078$ (Because of "is there is a statistically significant difference between the local sexual assault percentage and the national sexual assault percentage", this can be greater or less, but not equal to 0.00078, this is a two-tailed test)

# %% [markdown]
# ### **2. Are the conditions $\mathbf{np} \ge \mathbf{10}$ and $\mathbf{n(1-p)} \ge \mathbf{10}$ met?**

# %%
n = 37937
p_hat = 11 / 37937 # Success of the sample (0.00028995), not the population
# This will equal `11 >= 10`
assert n * p_hat >= 10
# This will equal `37926 >= 10`
assert n * (1 - p_hat) >= 10
# Both conditions are satisfied

# %% [markdown]
# ### **3. Choose the distribution and parameters.**

# %% [markdown]
# Because the problem contains no mention of a mean, this is a proportion-based one sample test. The sample size is large enough to use a normal distribution to approximate the binomial trials of a sample of size 37937.
#
# **Random Variable**: $P^\prime$ is the proportion of sexual assaults in Daviess County, KY.
#
# $P^\prime \sim N\left(p, \sqrt{\frac{p(1 - p)}{n}} \right)$
#
# $P^\prime \sim N\left(0.00078, \sqrt{\frac{0.00078(1 - 0.00078)}{37937}} \right)$ where $p=0.00078, q = 1 - 0.00078$ and $n = 37937$

# %% [markdown]
# ### **4. Calculate statistic and $p$ value of 1-Sample Two-Sided Z-Test**

# %%
from statsmodels.stats.proportion import proportions_ztest

sample_success = 11
sample_size = 37937

p_null = 0.00078 # null hypothesis
alpha = 0.01

# Output z_stat and p_value
z_stat, p_value = proportions_ztest(
    count=sample_success, # number of successes in the sample
    nobs=sample_size, # number of observations
    value=p_null, # value is the null hypothesis, or population proportion
    alternative="two-sided",
    prop_var=False # false means to use sample data for variance
)
print(f"The z-statistic of the test = {z_stat} and p-value = {p_value}")
# Out:
# The z-statistic of the test = -5.606168020918838 and p-value = 2.068551623754624e-08

# %% [markdown]
# ### **5:  Make a decision about $H_0$ by comparing the $p$ values and statistical significance level $\alpha$**

# %% [markdown]
# Based on our p-value of $0.000000002068551623754624 \lt 0.01$ (statistically significant level), the sample data provides sufficient evidence to reject the null hypothesis

# %% [markdown]
# ### **6. Write a conclusion about the problem based on the result of the Hypothesis test**

# %% [markdown]
# Based on our data, there is enough evidence to reject the null hypothesis. At the 1% statistical significance, the sample data shows sufficient evidence that the difference in the percentage of sexual assualt causes in Daviess County, KY is statistically significant at the 0.01 significance level.

# %% [markdown]
# ### **7: Write about any possible sources of error or other factors that could affect our hypothesis test.**

# %% [markdown]
# With any data about sexual assault, we need to be very careful about how data is collected, as the numbers tend to be underreported.

# %% [markdown]
# ### **8. Graph the distribution and $p$-value.**
# >> * #### **Hint 1:** If the inputs below you enter agree with the parameter variables used in creating the plot, you should see a plot with arrows pointing to the critical values at the statistically significant level $\alpha$ and test statistic, respectively.
#
# >> * #### **Hint 2:** Use as many decimal places as possible.
#
# >> * #### **Hint 3:** If you do not enter the correct p values or type of the hypothesis test, the App will output a message and exit.

# %%
#@title Enter the values for the hypothesis test from your computation above
# @markdown Enter the number of sunccess of the sample
x_success_sample = 11 #@param {type:"number"}
# @markdown Enter the sample size $n$
n = 37937 #@param {type:"integer"}
# @markdown Enter the <font color = "red"> probability of success of each binomial trial </font><br>(proportion for the $H_0$ Hypothesis)
p_null = 0.00078 #@param {type:"number"}
# @markdown Enter the <font color = "red"> p value </font> from your hypothesis test with at least seven decimal places)
p_value = 0.00000002068551623754624 #@param {type:"number"}
#@markdown Choose the probability distribution you used for this hypothesis testing
p_distribution = "Normal Distribution" # @param ["Normal Distribution", "Student's t Distribution", "Chi-Square Distribution","f Distribution", "None"]
#@markdown Choose the type of this hypothesis testing
Test_types = "Two-tailed hypothesis test" # @param ["Left-tailed hypothesis test", "Right-tailed hypothesis test", "Two-tailed hypothesis test","None"]
# @markdown Enter the statistically significant level
alpha = 0.01 #@param {type:"number"}

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats  as stats
import sys # at top of file
# %matplotlib inline


# input value of the ransom variable and parameters of the normal distribution
# x_low < X < x_high: value of the random variable with a normal distribution
mu = p_null                # mean
std = np.sqrt(mu * (1 - mu) /n)             # standard deviation

# compute the higher limit of proportion

p_sample = x_success_sample / n # sample proportion of success

# find where p_sample is on the left or right of p_null
if (p_sample >= mu ):
  x_high = p_sample
  x_low = mu - (x_high - mu)
else:
  x_low = p_sample
  x_high = mu  + (mu - x_low) # lower proportion for p-value

#Compute the p value for two tailed test
"""
p_value = 2 * stats.norm.cdf(x= x_low,  #value of the random variable
                      loc = mu,    # mean
                      scale= std   # standard deviation
                      )
"""
if ((p_value < 0) or (p_value > 0.00000005)):
    print("The p values was not accurate, check the prameters you entered in STEP 4.")
    print("If you entered the accurate p value, a graph will show.")
    sys.exit()
elif Test_types != "Two-tailed hypothesis test":
    print("The type of hypothesis does not agree with your hypothesis.  Check the proporty of this probability distribution ")
    sys.exit()
elif (p_distribution != "Normal Distribution"):
    print("Reread the problem and chek the sample sizes to see what probability distribution you need to use.")
    sys.exit()

#print(f"p value = {p_value}, std {std}")
# Plot normal distribution areas*

plt.figure(figsize = (12, 8 ))
x_lower = mu - 6 * std
x_higher = mu + 6 * std

#add the density curve ppf to the plot
x_pdf = np.arange(x_lower, x_higher,0.00001) # array of input values for pdf
y_pdf = stats.norm.pdf(x_pdf, loc = mu, scale = std)
plt.plot(x_pdf, y_pdf, color='black', linewidth = 2)

plt.fill_between(x_pdf, y_pdf, where = (x_pdf < x_low ) | ( x_pdf > x_high), facecolor = "lightgreen", alpha = 0.5)

# compute the critical value for a two-tailed test
x_ct = stats.norm.ppf(alpha/2, loc=mu, scale=std)
y_ct = stats.norm.pdf(x_ct, loc = mu, scale = std)

plt.vlines(x_ct, 0, y_ct, colors="red", linestyles='solid', label='critical point', linewidth = 4)

plt.vlines(2 * mu - x_ct, 0, y_ct, colors="red", linestyles='solid', linewidth = 4)

plt.annotate(r'Critical Value at $\alpha/ 2$', xy =(x_ct, 0),
                xytext =(mu - 0.00015, 400),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)

plt.annotate(r'Critical Value at $\alpha/ 2$', xy =(2 * mu - x_ct, 0),
                xytext =(mu - 0.00015, 400),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)


plt.annotate(r"$p_{sample}$'s", xy =(x_low, 0),
                xytext =(mu - 0.00001, 800),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12
             )

plt.annotate(r"$p_{sample}$'s", xy =(x_high, 0),
                xytext =(mu - 0.00001, 800),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12
              )

y_label = -400


plt.text(x = mu - 0.0001, y= y_label, s= r"$p_{H_{0}}=$"+f"{mu}", fontsize=12, )
plt.text(x = mu - 0.0001, y= y_label - 200, s= r"Proportion $P$", fontsize=14, )

x_text = mu - 3.5 * std

y_text = 1000

plt.text(x = mu - 4 * std, y= y_text, fontsize=15,
         s = "Shaded area\n represents \n probability \n" + r"$P(p < p_{sample})$" + "\n=(1/2) p-value\n=" + str(round(p_value / 2,3)))
plt.text(x = mu + 3 * std, y= y_text, fontsize=15,
         s = "Shaded area\n represents \n probability \n" + r"$P(p >2p_{H_0} - p_{sample})$" + "\n=(1/2) p-value\n=" + str(round(p_value / 2,3)))
plt.text(mu + 3 * std, y_text - 300, fontsize=15, s =r'$\alpha = $' + str(alpha))

plt.ylabel('Normal Probability Density Function', fontsize = 14)
#plt.legend(loc='best')
#plt.xlabel(r"Proportion $P$", fontsize = 14,)


ax = plt.subplot()
ax.set_yticklabels([])

#ax.xaxis.set_label_coords(0.5, -700)
plt.title("One Population Proportion Hypothesis Test of Binomial Trials\n wuth Normal Approdimation ", fontsize = 14)

plt.show()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **$\color{green}{\textbf{ TODO 2: }}$ Perform the appropriate hypothesis test.**

# %% [markdown]
# <details>
#   <summary><b> Show the problem </b></summary>
#
# In a study of 420,019 cell phone users, 172 of the subjects developed brain cancer. Test the claim that cell phone users developed brain cancer at a greater rate than that for non-cell phone users (the rate of brain cancer for non-cell phone users is 0.0340%). Since this is a critical issue, use a 0.005 significance
# level.
#
# </details>

# %% [markdown]
# <details>
# <summary><b> Why Low Significance Level </b></summary>
# If we commit a Type I error (a type I error is the rejection of a true null hypothesis (also known as a "false positive"), we are essentially accepting a false claim ($H_{a}$ (More cancer case for cell phone users). Since the claim describes cancer-causing environments, we want to minimize the chances of incorrectly identifying the causes of cancer.
# </details>

# %% [markdown]
# ### **1. Setup the hypothesis**

# %% [markdown]
# $H_o : p = 0.000340$
#
# $H_a : p \gt 0.000340$
#
# This is a right-tailed test
#
# $\alpha = 0.005$

# %% [markdown]
# ### **2.** Verify Requirement 2 that both $\mathbf{np} \ge \mathbf{10}$ and $\mathbf{n(1-p)} \ge \mathbf{10}$

# %% [markdown]
# $np_{\text{success}} {sample} = 420,019 \cdot 0.000340 = 142.8 \geq 10$
#
# $n(1 - p_{\text{success}}) (sample) = 420,019 \cdot (1 - 0.000340) = 419,876 \geq 10$

# %%
n = 420019
p_null = 0.000340

# 420019 * 0.00034 = 142.8 >= 10
assert n * p_null >= 10
# 420019 * (1 - 0.00034) = 419876 >= 10
assert n * (1 - p_null) >= 10

# %% [markdown]
# ### **3. Choose Distributions**

# %% [markdown]
# The problem contains no mention of a mean. Therefore, this is a proportion-based one sample test. The sample size is large enough to use a normal distribution to approximate the binomial trials of a sample of size 420,019.
#
# **Random Variable**: $P^\prime$ is the proportion of non-cell phone users with brain cancer.
#
# $P^\prime \sim N\left(p, \sqrt{\frac{p(1 - p)}{n}} \right)$
#
# $P^\prime \sim N\left(0.00034, \sqrt{\frac{0.00034(1 - 0.00034)}{420,019}} \right)$ where $p=0.00034, q = 1 - 0.00034$ and $n = 420,019$

# %% [markdown]
# ### **4. Write Python Code to Perform 1-Sample Z-Test:  Calculate the test statistic and $p$-value**

# %%
from statsmodels.stats.proportion import proportions_ztest

sample_success = 172
sample_size = 420019
p_null = 0.00034 # null hypothesis
alpha = 0.005
test_type = "larger" # represents the left tail

# Output z_stat and p_value
z_stat, p_value = proportions_ztest(
    count=sample_success, # number of successes in the sample
    nobs=sample_size, # number of observations
    value=p_null, # value is the null hypothesis, or population proportion
    alternative=test_type,
    prop_var=False # false means to use sample data for variance
)
print(f"The z-statistic of the test = {z_stat} and p-value = {p_value}")
# Out:
# The z-statistic of the test = 2.2264424731326544 and p-value = 0.012992279107594148

# %% [markdown]
# ### **5:  Make a decision about $H_0$ by comparing the $p$ values and statistical significance level $\alpha$**

# %% [markdown]
# Based on our p-value of 0.012992279107594148 > 0.005 (statistically significant level), the sample data does not provide sufficient evidence to reject the null hypothesis

# %% [markdown]
# ### **6. Write a conclusion about the problem based on the result of the Hypothesis test**

# %% [markdown]
# At the 0.005 statistical significance level, the sample data does not support the original claim that cell phone users developed brain cancer at a rate greater than non-cell phone users.

# %% [markdown]
# ### **7: Write about any possible sources of error or other factors that could affect our hypothesis test.**

# %% [markdown]
# The data that was used to generate this sample could be out of date, as new cell phone models or technologies may introduce changes. Additionally, longer term exposure may have different impacts as people use cell phones more.

# %% [markdown]
# ### **8. Graph the distribution and $p$-value.**
# >> * #### **Hint 1:** If the inputs below you enter agree with the parameter variables used in creating the plot, you should see a plot with arrows pointing to the critical values at the statistically significant level $\alpha$ and test statistic, respectively.
#
# >> * #### **Hint 2:** Use as many decimal places as possible.
#
# >> * #### **Hint 3:** If you do not enter the correct p values or type of the hypothesis test, the App will output a message and exit.

# %%
#@title Enter the values for the hypothesis test from your computation above
# @markdown Enter the number of sunccess of the sample
x_success_sample = 172 #@param {type:"number"}
# @markdown Enter the sample size $n$
n = 420019 #@param {type:"integer"}
# @markdown Enter the <font color = "red"> probability of success of each binomial trial </font><br>(proportion for the $H_0$ Hypothesis)
p_null = 0.00034 #@param {type:"number"}
# @markdown Enter the <font color = "red"> p value </font> from your hypothesis test with at least seven decimal places)
p_value = 0.012992279107594148 #@param {type:"number"}
#@markdown Choose the probability distribution you used for this hypothesis testing
p_distribution = "Normal Distribution" # @param ["Normal Distribution", "Student's t Distribution", "Chi-Square Distribution","f Distribution", "None"]
#@markdown Choose the type of this hypothesis testing
Test_types = "Right-tailed hypothesis test" # @param ["Left-tailed hypothesis test", "Right-tailed hypothesis test", "Two-tailed hypothesis test","None"]
# @markdown Enter the statistically significant level
alpha = 0.005 #@param {type:"number"}

import sys # at top of file

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats  as stats

# %matplotlib inline


# input value of the ransom variable and parameters of the normal distribution
# X > x_high: value of the random variable with a normal distribution
mu = p_null                # mean
std = np.sqrt(mu * (1 - mu) /n)             # standard deviation

# compute the higher limit of proportion

p_sample = x_success_sample / n # sample proportion of success

# find where p_sample is on the left or right of p_null
if (p_sample >= mu ):
  x_high = p_sample
  x_low = mu - (x_high - mu)
else:
  x_low = p_sample
  x_high = mu  + (mu - x_low) # lower proportion for p-value

if ((p_value < 0.01299) or (p_value > 0.01300)):
    print("The p values was not accurate, check the prameters you entered in STEP 4.")
    print("If you entered the accurate p value, a graph will show.")
    sys.exit()
elif Test_types != "Right-tailed hypothesis test":
    print("The type of hypothesis does not agree with your hypothesis.  Check the proporty of this probability distribution ")
    sys.exit()
elif (p_distribution != "Normal Distribution"):
    print("Reread the problem and chek the sample sizes to see what probability distribution you need to use.")
    sys.exit()
plt.figure(figsize = (12, 8 ))
x_lower = mu - 4 * std
x_higher = mu + 4 * std

#add the density curve ppf to the plot
x_pdf = np.arange(x_lower, x_higher,0.000001) # array of input values for pdf
y_pdf = stats.norm.pdf(x_pdf, loc = mu, scale = std)
plt.plot(x_pdf, y_pdf, color='black', linewidth = 2)

plt.fill_between(x_pdf, y_pdf, where = x_pdf > x_high, facecolor = "purple", alpha = 0.5)

# compute the critical value for a two-tailed test
x_ct = stats.norm.ppf(alpha/2, loc=mu, scale=std)
y_ct = stats.norm.pdf(x_ct, loc = mu, scale = std)

#plt.vlines(x_ct, 0, y_ct, colors="red", linestyles='solid', label='critical point', linewidth = 4)

plt.vlines(2 * mu - x_ct, 0, y_ct, colors="red", linestyles='solid', linewidth = 4)

"""
plt.annotate(r'Critical Value at $\alpha/ 2$', xy =(x_ct, 0),
                xytext =(mu - 0.00015, 400),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)


plt.annotate(r"$p_{sample}$'s", xy =(x_low, 0),
                xytext =(mu - 0.00001, 800),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)
"""
plt.annotate(r'Critical Value at $\alpha$', xy =(2 * mu - x_ct, 0),
                xytext =(x_high + 0.00002, 2000), ha = "center",
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12)

plt.annotate(r"$p_{sample}$'s", xy =(x_high, 0),
                xytext =(mu + 0.00002, 2000),
                arrowprops = dict(facecolor ='green',
                shrink = 0.01), fontsize = 12
              )

y_label = -2000


plt.text(x = mu, y= y_label, s= r"$p_{H_{0}}=$"+f"{mu}", fontsize=12, )
plt.text(x = mu, y= y_label - 1000, s= r"Proportion $P$", fontsize=14, )

x_text = mu - 3.5 * std

y_text = 5000

#plt.text(x = mu - 3 * std, y= y_text, fontsize=15,
#         s = "Shaded area\n represents \n probability \n" + r"$P(p < p_{sample})$" + "\n=(1/2) p-value\n=" + str(round(p_value / 2,3)))
plt.text(x = mu + 2 * std, y= y_text, fontsize=15,
         s = "Shaded area\n represents \n probability \n" + r"$P(p >2p_{H_0} - p_{sample})$" + "\n=p-value\n=" + str(round(p_value,6)))
#plt.text(mu + 2 * std, y_text - 300, fontsize=15, s =r'$\alpha = $' + str(alpha))

plt.ylabel('Normal Probability Density Function', fontsize = 14)
#plt.legend(loc='best')
#plt.xlabel(r"Proportion $P$", fontsize = 14,)


ax = plt.subplot()
ax.set_yticklabels([])

#ax.xaxis.set_label_coords(0.5, -700)
plt.title("One Population Proportion Hypothesis Test of Binomial Trials\n wuth Normal Approximation ", fontsize = 14)

plt.show()
